# %%
import glob
import os
import random
import spacy
import string
from sklearn.model_selection import train_test_split 
import pickle as pkl
import nltk
from nltk.util import ngrams
from collections import Counter
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from torch.utils.data import Dataset
from sklearn.model_selection import ParameterGrid
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Read Train Data

# %%
file_list_pos = glob.glob(os.path.join(os.getcwd(), "aclImdb/train/pos/", "*.txt"))
file_list_neg = glob.glob(os.path.join(os.getcwd(), "aclImdb/train/neg/", "*.txt"))

train = []

for file_path in file_list_pos:
    with open(file_path) as f_input:
        train.append([f_input.read(),1])
train
for file_path in file_list_neg:
    with open(file_path) as f_input:
        train.append([f_input.read(),0])
        
# print (train[random.randint(0, len(train) - 1)])

# %% [markdown]
# # Read Test Data

# %%
file_list_pos = glob.glob(os.path.join(os.getcwd(), "aclImdb/test/pos/", "*.txt"))
file_list_neg = glob.glob(os.path.join(os.getcwd(), "aclImdb/test/neg/", "*.txt"))

test = []

for file_path in file_list_pos:
    with open(file_path) as f_input:
        test.append([f_input.read(),1])

for file_path in file_list_neg:
    with open(file_path) as f_input:
        test.append([f_input.read(),0])
        
# print (test[random.randint(0, len(test) - 1)])

# %% [markdown]
# # Split train data into train and val data

# %%
X_train = [i[0] for i in train]
y_train = [i[1] for i in train]

X_test = [i[0] for i in test]
y_test = [i[1] for i in test]

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 5000, random_state = 42)

# %%
print(len(X_train),len(X_val),len(X_test))
print(len(y_train),len(y_val),len(y_test))
# Out:
# 20000 5000 25000
# 20000 5000 25000

# %% [markdown]
# # Tokenizing

# %%
# Load English tokenizer, tagger, parser, NER and word vectors
tokenizer = spacy.load('en_core_web_sm')
punctuations = string.punctuation

# lowercase and remove punctuation
def tokenize(sent):
    tokens = tokenizer(sent)
    return [token.text.lower() for token in tokens if (token.text not in punctuations)]


def tokenize_dataset(dataset):
    token_dataset = []
    # we are keeping track of all tokens in dataset 
    # in order to create vocabulary later
    all_tokens = []
    
    for sample in dataset:
        tokens = tokenize(sample)
        token_dataset.append(tokens)
        all_tokens += tokens

    return token_dataset, all_tokens

# %%
# # val set tokens
# print ("Tokenizing val data")
# val_data_tokens, _ = tokenize_dataset(X_val)
# pkl.dump(val_data_tokens, open("val_data_tokens.p", "wb"))

# # test set tokens
# print ("Tokenizing test data")
# test_data_tokens, _ = tokenize_dataset(X_test)
# pkl.dump(test_data_tokens, open("test_data_tokens.p", "wb"))

# # train set tokens
# print ("Tokenizing train data")
# train_data_tokens, all_train_tokens = tokenize_dataset(X_train)
# pkl.dump(train_data_tokens, open("train_data_tokens.p", "wb"))
# pkl.dump(all_train_tokens, open("all_train_tokens.p", "wb"))

# %%
# reload pickle
train_data_tokens = pkl.load(open("train_data_tokens.p", "rb")) 
### each sentence is lowercase and remove punctuation and there is a big list of smaller list
### each small list is the split words of the ogirinal text sentect
all_train_tokens = pkl.load(open("all_train_tokens.p", "rb"))  ### all unigram vocubular

val_data_tokens = pkl.load(open("val_data_tokens.p", "rb"))
test_data_tokens = pkl.load(open("test_data_tokens.p", "rb"))

# %% [markdown]
# # N-grams

# %%
max_vocab_size = 10000
# save index 1 for unk and 0 for pad
PAD_IDX = 0
UNK_IDX = 1

def build_vocab(all_tokens,n):
    ## This function is to transfer unigram to n gram and return mapping criteria from token to index 
    # all_tokens = unigram token vocabulary 
    # n is n_grams
    # Returns:
    # id2token: list of tokens, where id2token[i] returns token that corresponds to token i
    # token2id: dictionary where keys represent tokens and corresponding values represent indices
    all_tokens = [' '.join(i) for i in ngrams(all_train_tokens,n)]  ## ngrams comes from NLTK
    token_counter = Counter(all_tokens)
    vocab, count = zip(*token_counter.most_common(max_vocab_size))
    id2token = list(vocab)
    token2id = dict(zip(vocab, range(2,2+len(vocab)))) 
    id2token = ['<pad>', '<unk>'] + id2token
    token2id['<pad>'] = PAD_IDX 
    token2id['<unk>'] = UNK_IDX
    return token2id, id2token   # token2id is the most important one

# %%
# convert token to id in the dataset
def token2index_dataset(tokens_data,all_train_tokens,n):
    token2id, id2token = build_vocab(all_train_tokens,n)
    
    indices_data = []
    for tokens in tokens_data:
        tokens = [' '.join(i) for i in ngrams(tokens,n)]
        index_list = [token2id[token] if token in token2id else UNK_IDX for token in tokens]
        indices_data.append(index_list)
    return indices_data,id2token

# %%
train_data_indices,id2token = token2index_dataset(train_data_tokens,all_train_tokens,4)
val_data_indices,_ = token2index_dataset(val_data_tokens,all_train_tokens,4)
test_data_indices, _ = token2index_dataset(test_data_tokens,all_train_tokens,4)

# double checking
print ("Train dataset size is {}".format(len(train_data_indices)))
print ("Val dataset size is {}".format(len(val_data_indices)))
print ("Test dataset size is {}".format(len(test_data_indices)))
# Out:
# Train dataset size is 20000
# Val dataset size is 5000
# Test dataset size is 25000

# %% [markdown]
# # Pytorch DataLoader

# %%
MAX_SENTENCE_LENGTH = 200

class ImdbDataset(Dataset):
    """
    Class that represents a train/validation/test dataset that's readable for PyTorch
    Note that this class inherits torch.utils.data.Dataset
    """
    
    def __init__(self, data_list, target_list):
        """
        @param data_list: list of newsgroup tokens 
        @param target_list: list of newsgroup targets 

        """
        self.data_list = data_list
        self.target_list = target_list
        assert (len(self.data_list) == len(self.target_list))

    def __len__(self):
        return len(self.data_list)
        
    def __getitem__(self, key):
        """
        Triggered when you call dataset[i]
        """
        
        token_idx = self.data_list[key][:MAX_SENTENCE_LENGTH]
        label = self.target_list[key]
        return [token_idx, len(token_idx), label]

def imdb_collate_func(batch):
    """
    Customized function for DataLoader that dynamically pads the batch so that all 
    data have the same length
    """
    data_list = []
    label_list = []
    length_list = []
    #print("collate batch: ", batch[0][0])
    #batch[0][0] = batch[0][0][:MAX_SENTENCE_LENGTH]
    for datum in batch:   ### batch = sample
        label_list.append(datum[2])
        length_list.append(datum[1])
    # padding
    for datum in batch:
        padded_vec = np.pad(np.array(datum[0]), 
                                pad_width=((0,MAX_SENTENCE_LENGTH-datum[1])),          ### 0代表左边没有pad,右边的值代表右边pad的个数
                                mode="constant", constant_values=0)
        data_list.append(padded_vec)
    return [torch.from_numpy(np.array(data_list)), torch.LongTensor(length_list), torch.LongTensor(label_list)]
#As another example, several loss functions like CrossEntropyLoss require that the target should be torch LongTensor. So before doing operations, make sure that your input Tensor types match the function definitions.


# create pytorch dataloader
#train_loader = NewsGroupDataset(train_data_indices, train_targets)
#val_loader = NewsGroupDataset(val_data_indices, val_targets)
#test_loader = NewsGroupDataset(test_data_indices, test_targets)

BATCH_SIZE = 32
train_dataset = ImdbDataset(train_data_indices, y_train)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=BATCH_SIZE,
                                           collate_fn=imdb_collate_func,   # collate_fn (callable, optional) – merges a list of samples to form a mini-batch.
                                           shuffle=True)
'''
- With data loader you can easily do :
- mini batches
- shuffling
- special sampling
- asynchronous loading with multiple workers
'''


val_dataset = ImdbDataset(val_data_indices, y_val)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, 
                                           batch_size=BATCH_SIZE,
                                           collate_fn=imdb_collate_func,
                                           shuffle=True)

test_dataset = ImdbDataset(test_data_indices, y_test)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                           batch_size=BATCH_SIZE,
                                           collate_fn=imdb_collate_func,
                                           shuffle=False)

#for i, (data, lengths, labels) in enumerate(train_loader):
#    print (data)
#    print (labels)
#    break

# %% [markdown]
# # Define bag-of-n-words model

# %%
class BagOfWords(nn.Module):
    """
    BagOfWords classification model
    """
    def __init__(self, vocab_size, emb_dim):
        """
        @param vocab_size: size of the vocabulary. |V|
        @param emb_dim: size of the word embedding  d
        """
        super(BagOfWords, self).__init__()
        # pay attention to padding_idx 
        self.embed = nn.Embedding(vocab_size, emb_dim, padding_idx=0)
        self.linear = nn.Linear(emb_dim,20)   # nn.Linear(input, output)
    
    def forward(self, data, length):
        """
        
        @param data: matrix of size (batch_size, max_sentence_length). Each row in data represents a 
            review that is represented using n-gram index. Note that they are padded to have same length.
        @param length: an int tensor of size (batch_size), which represents the non-trivial (excludes padding)
            length of each sentences in the data.
        """
        out = self.embed(data)
        out = torch.sum(out, dim=1)
        out /= length.view(length.size()[0],1).expand_as(out).float()
     
        # return logits
        out = self.linear(out.float())
        return out

# %% [markdown]
# # Running Model

# %%
# Function for testing the model
def test_model(loader, model):
    """
    Help function that tests the model's performance on a dataset
    @param: loader - data loader for the dataset to test against
    """
    correct = 0
    total = 0
    model.eval()
    for data, lengths, labels in loader:
        data_batch, length_batch, label_batch = data, lengths, labels
        outputs = F.softmax(model(data_batch, length_batch), dim=1)
        predicted = outputs.max(1, keepdim=True)[1]
        total += labels.size(0)  ### 一个batch有32个sample 所以labels.size(0) =32
        correct += predicted.eq(labels.view_as(predicted)).sum().item()
    return (100 * correct / total)

# %% [markdown]
# # Hyper-parameter Tuning

# %%
'''
ngrams         predefined 1,2,3,4
max_vocab_size predefined 10000,20000
emb_dim        grid       100,200,300,400,500
optimizer      grid       'Adam','Sgd'
lr_rate        grid       0.0005,0.001,0.005
'''


def tuning(emb_dim, optimizer, learning_rate):
    BATCH_SIZE = 32
    train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                               batch_size=BATCH_SIZE,
                                               collate_fn=imdb_collate_func,   # collate_fn (callable, optional) – merges a list of samples to form a mini-batch.
                                               shuffle=True)

    val_dataset = ImdbDataset(val_data_indices, y_val)
    val_loader = torch.utils.data.DataLoader(dataset=val_dataset, 
                                               batch_size=BATCH_SIZE,
                                               collate_fn=imdb_collate_func,
                                               shuffle=True)

    test_dataset = ImdbDataset(test_data_indices, y_test)
    test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                               batch_size=BATCH_SIZE,
                                               collate_fn=imdb_collate_func,
                                               shuffle=False)
    model = BagOfWords(len(id2token), emb_dim)
    num_epochs = 10 # number epoch to train

    # Criterion and Optimizer
    criterion = torch.nn.CrossEntropyLoss()  
    opt = 'torch.optim.'+ optimizer + '(model.parameters(), lr=learning_rate)'
    optimizer = eval(opt)

    for epoch in range(num_epochs):
        for i, (data, lengths, labels) in enumerate(train_loader):
            model.train()
            data_batch, length_batch, label_batch = data, lengths, labels
            optimizer.zero_grad()
            outputs = model(data_batch, length_batch)
            loss = criterion(outputs, label_batch)
    #         print(loss)
            loss.backward()
            optimizer.step()
            # validate every 100 iterations
            if i > 0 and i % 624 == 0:
                # validate
                val_acc = test_model(val_loader, model)
                print('Epoch: [{}/{}], Step: [{}/{}], Validation Acc: {}'.format(
                    epoch+1, num_epochs, i+1, len(train_loader), val_acc))
    print(test_model(test_loader,model))

# %% [markdown]
# # ngram = 1, max_vocab_size = 10000

# %%
grid = {'emb_dim':[100,200,300,400,500],'optimizer':['Adam','RMSprop'], 'learning_rate': [0.0005,0.001,0.005]}
num_comb = len(ParameterGrid(grid))
count = 0

for j in range(len(ParameterGrid(grid))):
    count += 1
    print("Now it is {} out of {} combinations".format(count, num_comb))
    optimizer,learning_rate, emb_dim = ParameterGrid(grid)[j].values()
    myCsvRow = "optimizer = {}, learning_rate = {}, emb_dim = {}".format(optimizer, learning_rate, emb_dim)
    print(myCsvRow)
    tuning(emb_dim, optimizer, learning_rate)
    print()
# Out:
# Now it is 1 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 64.5
# Epoch: [2/10], Step: [625/625], Validation Acc: 73.34
# Epoch: [3/10], Step: [625/625], Validation Acc: 78.58
# Epoch: [4/10], Step: [625/625], Validation Acc: 80.74
# Epoch: [5/10], Step: [625/625], Validation Acc: 82.54
# Epoch: [6/10], Step: [625/625], Validation Acc: 83.62
# Epoch: [7/10], Step: [625/625], Validation Acc: 84.42
# Epoch: [8/10], Step: [625/625], Validation Acc: 84.76
# Epoch: [9/10], Step: [625/625], Validation Acc: 85.16
# Epoch: [10/10], Step: [625/625], Validation Acc: 85.68
# 85.072
#
# Now it is 2 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 67.68
# Epoch: [2/10], Step: [625/625], Validation Acc: 75.22
# Epoch: [3/10], Step: [625/625], Validation Acc: 79.54
# Epoch: [4/10], Step: [625/625], Validation Acc: 81.52
# Epoch: [5/10], Step: [625/625], Validation Acc: 82.84
# Epoch: [6/10], Step: [625/625], Validation Acc: 83.88
# Epoch: [7/10], Step: [625/625], Validation Acc: 84.28
# Epoch: [8/10], Step: [625/625], Validation Acc: 84.92
# Epoch: [9/10], Step: [625/625], Validation Acc: 85.58
# Epoch: [10/10], Step: [625/625], Validation Acc: 85.92
# 85.604
#
# Now it is 3 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 73.58
# Epoch: [2/10], Step: [625/625], Validation Acc: 81.26
# Epoch: [3/10], Step: [625/625], Validation Acc: 83.46
# Epoch: [4/10], Step: [625/625], Validation Acc: 84.92
# Epoch: [5/10], Step: [625/625], Validation Acc: 85.68
# Epoch: [6/10], Step: [625/625], Validation Acc: 86.48
# Epoch: [7/10], Step: [625/625], Validation Acc: 86.74
# Epoch: [8/10], Step: [625/625], Validation Acc: 86.64
# Epoch: [9/10], Step: [625/625], Validation Acc: 86.84
# Epoch: [10/10], Step: [625/625], Validation Acc: 86.56
# 85.58
#
# Now it is 4 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 75.64
# Epoch: [2/10], Step: [625/625], Validation Acc: 81.6
# Epoch: [3/10], Step: [625/625], Validation Acc: 83.28
# Epoch: [4/10], Step: [625/625], Validation Acc: 84.48
# Epoch: [5/10], Step: [625/625], Validation Acc: 85.66
# Epoch: [6/10], Step: [625/625], Validation Acc: 86.22
# Epoch: [7/10], Step: [625/625], Validation Acc: 86.48
# Epoch: [8/10], Step: [625/625], Validation Acc: 86.72
# Epoch: [9/10], Step: [625/625], Validation Acc: 86.74
# Epoch: [10/10], Step: [625/625], Validation Acc: 86.74
# 85.088
#
# Now it is 5 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 84.94
# Epoch: [2/10], Step: [625/625], Validation Acc: 86.44
# Epoch: [3/10], Step: [625/625], Validation Acc: 86.3
# Epoch: [4/10], Step: [625/625], Validation Acc: 85.92
# Epoch: [5/10], Step: [625/625], Validation Acc: 85.4
# Epoch: [6/10], Step: [625/625], Validation Acc: 84.7
# Epoch: [7/10], Step: [625/625], Validation Acc: 84.44
# Epoch: [8/10], Step: [625/625], Validation Acc: 84.3
# Epoch: [9/10], Step: [625/625], Validation Acc: 83.86
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.6
# 81.164
#
# Now it is 6 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 84.86
# Epoch: [2/10], Step: [625/625], Validation Acc: 86.8
# Epoch: [3/10], Step: [625/625], Validation Acc: 86.42
# Epoch: [4/10], Step: [625/625], Validation Acc: 86.02
# Epoch: [5/10], Step: [625/625], Validation Acc: 85.62
# Epoch: [6/10], Step: [625/625], Validation Acc: 85.22
# Epoch: [7/10], Step: [625/625], Validation Acc: 85.14
# Epoch: [8/10], Step: [625/625], Validation Acc: 84.2
# Epoch: [9/10], Step: [625/625], Validation Acc: 84.34
# Epoch: [10/10], Step: [625/625], Validation Acc: 84.1
# 81.54
#
# Now it is 7 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 70.4
# Epoch: [2/10], Step: [625/625], Validation Acc: 77.88
# Epoch: [3/10], Step: [625/625], Validation Acc: 81.24
# Epoch: [4/10], Step: [625/625], Validation Acc: 83.22
# Epoch: [5/10], Step: [625/625], Validation Acc: 84.44
# Epoch: [6/10], Step: [625/625], Validation Acc: 84.38
# Epoch: [7/10], Step: [625/625], Validation Acc: 85.54
# Epoch: [8/10], Step: [625/625], Validation Acc: 86.02
# Epoch: [9/10], Step: [625/625], Validation Acc: 86.0
# Epoch: [10/10], Step: [625/625], Validation Acc: 86.82
# 85.612
#
# Now it is 8 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 73.76
# Epoch: [2/10], Step: [625/625], Validation Acc: 79.26
# Epoch: [3/10], Step: [625/625], Validation Acc: 81.82
# Epoch: [4/10], Step: [625/625], Validation Acc: 83.82
# Epoch: [5/10], Step: [625/625], Validation Acc: 84.5
# Epoch: [6/10], Step: [625/625], Validation Acc: 85.24
# Epoch: [7/10], Step: [625/625], Validation Acc: 85.68
# Epoch: [8/10], Step: [625/625], Validation Acc: 86.2
# Epoch: [9/10], Step: [625/625], Validation Acc: 86.44
# Epoch: [10/10], Step: [625/625], Validation Acc: 86.28
# 85.996
#
# Now it is 9 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 78.2
# Epoch: [2/10], Step: [625/625], Validation Acc: 83.32
# Epoch: [3/10], Step: [625/625], Validation Acc: 85.26
# Epoch: [4/10], Step: [625/625], Validation Acc: 86.64
# Epoch: [5/10], Step: [625/625], Validation Acc: 86.78
# Epoch: [6/10], Step: [625/625], Validation Acc: 87.14
# Epoch: [7/10], Step: [625/625], Validation Acc: 86.96
# Epoch: [8/10], Step: [625/625], Validation Acc: 86.7
# Epoch: [9/10], Step: [625/625], Validation Acc: 86.62
# Epoch: [10/10], Step: [625/625], Validation Acc: 86.52
# 84.88
#
# Now it is 10 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 79.38
# Epoch: [2/10], Step: [625/625], Validation Acc: 83.5
# Epoch: [3/10], Step: [625/625], Validation Acc: 84.56
# Epoch: [4/10], Step: [625/625], Validation Acc: 86.2
# Epoch: [5/10], Step: [625/625], Validation Acc: 86.08
# Epoch: [6/10], Step: [625/625], Validation Acc: 86.76
# Epoch: [7/10], Step: [625/625], Validation Acc: 86.76
# Epoch: [8/10], Step: [625/625], Validation Acc: 87.34
# Epoch: [9/10], Step: [625/625], Validation Acc: 86.98
# Epoch: [10/10], Step: [625/625], Validation Acc: 86.84
# 85.216
#
# Now it is 11 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 85.78
# Epoch: [2/10], Step: [625/625], Validation Acc: 86.66
# Epoch: [3/10], Step: [625/625], Validation Acc: 85.52
# Epoch: [4/10], Step: [625/625], Validation Acc: 85.28
# Epoch: [5/10], Step: [625/625], Validation Acc: 84.54
# Epoch: [6/10], Step: [625/625], Validation Acc: 84.18
# Epoch: [7/10], Step: [625/625], Validation Acc: 83.9
# Epoch: [8/10], Step: [625/625], Validation Acc: 83.22
# Epoch: [9/10], Step: [625/625], Validation Acc: 83.42
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.18
# 80.652
#
# Now it is 12 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 86.36
# Epoch: [2/10], Step: [625/625], Validation Acc: 86.44
# Epoch: [3/10], Step: [625/625], Validation Acc: 86.24
# Epoch: [4/10], Step: [625/625], Validation Acc: 85.86
# Epoch: [5/10], Step: [625/625], Validation Acc: 85.06
# Epoch: [6/10], Step: [625/625], Validation Acc: 85.14
# Epoch: [7/10], Step: [625/625], Validation Acc: 84.58
# Epoch: [8/10], Step: [625/625], Validation Acc: 84.24
# Epoch: [9/10], Step: [625/625], Validation Acc: 83.96
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.68
# 80.956
#
# Now it is 13 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 73.02
# Epoch: [2/10], Step: [625/625], Validation Acc: 79.32
# Epoch: [3/10], Step: [625/625], Validation Acc: 83.06
# Epoch: [4/10], Step: [625/625], Validation Acc: 83.5
# Epoch: [5/10], Step: [625/625], Validation Acc: 84.88
# Epoch: [6/10], Step: [625/625], Validation Acc: 85.46
# Epoch: [7/10], Step: [625/625], Validation Acc: 86.12
# Epoch: [8/10], Step: [625/625], Validation Acc: 86.06
# Epoch: [9/10], Step: [625/625], Validation Acc: 86.62
# Epoch: [10/10], Step: [625/625], Validation Acc: 86.7
# 85.552
#
# Now it is 14 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 74.9
# Epoch: [2/10], Step: [625/625], Validation Acc: 80.36
# Epoch: [3/10], Step: [625/625], Validation Acc: 82.62
# Epoch: [4/10], Step: [625/625], Validation Acc: 84.28
# Epoch: [5/10], Step: [625/625], Validation Acc: 85.28
# Epoch: [6/10], Step: [625/625], Validation Acc: 85.1
# Epoch: [7/10], Step: [625/625], Validation Acc: 85.64
# Epoch: [8/10], Step: [625/625], Validation Acc: 85.86
# Epoch: [9/10], Step: [625/625], Validation Acc: 86.22
# Epoch: [10/10], Step: [625/625], Validation Acc: 86.36
# 86.048
#
# Now it is 15 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 79.78
# Epoch: [2/10], Step: [625/625], Validation Acc: 84.18
# Epoch: [3/10], Step: [625/625], Validation Acc: 85.58
# Epoch: [4/10], Step: [625/625], Validation Acc: 86.68
# Epoch: [5/10], Step: [625/625], Validation Acc: 86.66
# Epoch: [6/10], Step: [625/625], Validation Acc: 86.76
# Epoch: [7/10], Step: [625/625], Validation Acc: 86.64
# Epoch: [8/10], Step: [625/625], Validation Acc: 86.34
# Epoch: [9/10], Step: [625/625], Validation Acc: 86.24
# Epoch: [10/10], Step: [625/625], Validation Acc: 85.88
# 84.092
#
# Now it is 16 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 80.98
# Epoch: [2/10], Step: [625/625], Validation Acc: 84.36
# Epoch: [3/10], Step: [625/625], Validation Acc: 85.6
# Epoch: [4/10], Step: [625/625], Validation Acc: 86.46
# Epoch: [5/10], Step: [625/625], Validation Acc: 86.8
# Epoch: [6/10], Step: [625/625], Validation Acc: 86.88
# Epoch: [7/10], Step: [625/625], Validation Acc: 86.86
# Epoch: [8/10], Step: [625/625], Validation Acc: 86.86
# Epoch: [9/10], Step: [625/625], Validation Acc: 86.82
# Epoch: [10/10], Step: [625/625], Validation Acc: 86.32
# 84.584
#
# Now it is 17 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 86.12
# Epoch: [2/10], Step: [625/625], Validation Acc: 86.22
# Epoch: [3/10], Step: [625/625], Validation Acc: 85.3
# Epoch: [4/10], Step: [625/625], Validation Acc: 85.1
# Epoch: [5/10], Step: [625/625], Validation Acc: 84.3
# Epoch: [6/10], Step: [625/625], Validation Acc: 84.04
# Epoch: [7/10], Step: [625/625], Validation Acc: 83.58
# Epoch: [8/10], Step: [625/625], Validation Acc: 83.2
# Epoch: [9/10], Step: [625/625], Validation Acc: 83.26
# Epoch: [10/10], Step: [625/625], Validation Acc: 82.78
# 80.548
#
# Now it is 18 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 85.32
# Epoch: [2/10], Step: [625/625], Validation Acc: 86.88
# Epoch: [3/10], Step: [625/625], Validation Acc: 86.34
# Epoch: [4/10], Step: [625/625], Validation Acc: 85.6
# Epoch: [5/10], Step: [625/625], Validation Acc: 85.06
# Epoch: [6/10], Step: [625/625], Validation Acc: 84.64
# Epoch: [7/10], Step: [625/625], Validation Acc: 83.96
# Epoch: [8/10], Step: [625/625], Validation Acc: 83.76
# Epoch: [9/10], Step: [625/625], Validation Acc: 83.32
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.38
# 81.132
#
# Now it is 19 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 74.22
# Epoch: [2/10], Step: [625/625], Validation Acc: 81.06
# Epoch: [3/10], Step: [625/625], Validation Acc: 83.22
# Epoch: [4/10], Step: [625/625], Validation Acc: 84.78
# Epoch: [5/10], Step: [625/625], Validation Acc: 85.36
# Epoch: [6/10], Step: [625/625], Validation Acc: 86.02
# Epoch: [7/10], Step: [625/625], Validation Acc: 86.48
# Epoch: [8/10], Step: [625/625], Validation Acc: 86.44
# Epoch: [9/10], Step: [625/625], Validation Acc: 86.6
# Epoch: [10/10], Step: [625/625], Validation Acc: 86.72
# 85.584
#
# Now it is 20 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 76.12
# Epoch: [2/10], Step: [625/625], Validation Acc: 81.04
# Epoch: [3/10], Step: [625/625], Validation Acc: 83.5
# Epoch: [4/10], Step: [625/625], Validation Acc: 83.9
# Epoch: [5/10], Step: [625/625], Validation Acc: 85.44
# Epoch: [6/10], Step: [625/625], Validation Acc: 86.16
# Epoch: [7/10], Step: [625/625], Validation Acc: 86.48
# Epoch: [8/10], Step: [625/625], Validation Acc: 86.7
# Epoch: [9/10], Step: [625/625], Validation Acc: 86.92
# Epoch: [10/10], Step: [625/625], Validation Acc: 86.96
# 85.888
#
# Now it is 21 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 81.08
# Epoch: [2/10], Step: [625/625], Validation Acc: 84.72
# Epoch: [3/10], Step: [625/625], Validation Acc: 86.0
# Epoch: [4/10], Step: [625/625], Validation Acc: 86.48
# Epoch: [5/10], Step: [625/625], Validation Acc: 86.58
# Epoch: [6/10], Step: [625/625], Validation Acc: 86.56
# Epoch: [7/10], Step: [625/625], Validation Acc: 86.26
# Epoch: [8/10], Step: [625/625], Validation Acc: 86.1
# Epoch: [9/10], Step: [625/625], Validation Acc: 85.94
# Epoch: [10/10], Step: [625/625], Validation Acc: 85.54
# 83.82
#
# Now it is 22 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 82.16
# Epoch: [2/10], Step: [625/625], Validation Acc: 83.74
# Epoch: [3/10], Step: [625/625], Validation Acc: 85.9
# Epoch: [4/10], Step: [625/625], Validation Acc: 85.96
# Epoch: [5/10], Step: [625/625], Validation Acc: 86.96
# Epoch: [6/10], Step: [625/625], Validation Acc: 86.8
# Epoch: [7/10], Step: [625/625], Validation Acc: 86.94
# Epoch: [8/10], Step: [625/625], Validation Acc: 86.56
# Epoch: [9/10], Step: [625/625], Validation Acc: 86.54
# Epoch: [10/10], Step: [625/625], Validation Acc: 86.44
# 84.276
#
# Now it is 23 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 86.54
# Epoch: [2/10], Step: [625/625], Validation Acc: 85.98
# Epoch: [3/10], Step: [625/625], Validation Acc: 85.38
# Epoch: [4/10], Step: [625/625], Validation Acc: 84.18
# Epoch: [5/10], Step: [625/625], Validation Acc: 84.44
# Epoch: [6/10], Step: [625/625], Validation Acc: 83.9
# Epoch: [7/10], Step: [625/625], Validation Acc: 83.08
# Epoch: [8/10], Step: [625/625], Validation Acc: 83.04
# Epoch: [9/10], Step: [625/625], Validation Acc: 82.92
# Epoch: [10/10], Step: [625/625], Validation Acc: 82.72
# 80.12
#
# Now it is 24 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 83.76
# Epoch: [2/10], Step: [625/625], Validation Acc: 84.92
# Epoch: [3/10], Step: [625/625], Validation Acc: 86.2
# Epoch: [4/10], Step: [625/625], Validation Acc: 85.1
# Epoch: [5/10], Step: [625/625], Validation Acc: 85.2
# Epoch: [6/10], Step: [625/625], Validation Acc: 84.26
# Epoch: [7/10], Step: [625/625], Validation Acc: 84.34
# Epoch: [8/10], Step: [625/625], Validation Acc: 83.54
# Epoch: [9/10], Step: [625/625], Validation Acc: 83.66
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.62
# 80.644
#
# Now it is 25 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 75.6
# Epoch: [2/10], Step: [625/625], Validation Acc: 80.34
# Epoch: [3/10], Step: [625/625], Validation Acc: 83.76
# Epoch: [4/10], Step: [625/625], Validation Acc: 85.02
# Epoch: [5/10], Step: [625/625], Validation Acc: 85.84
# Epoch: [6/10], Step: [625/625], Validation Acc: 86.04
# Epoch: [7/10], Step: [625/625], Validation Acc: 86.68
# Epoch: [8/10], Step: [625/625], Validation Acc: 86.5
# Epoch: [9/10], Step: [625/625], Validation Acc: 86.74
# Epoch: [10/10], Step: [625/625], Validation Acc: 86.6
# 85.36
#
# Now it is 26 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 76.3
# Epoch: [2/10], Step: [625/625], Validation Acc: 81.58
# Epoch: [3/10], Step: [625/625], Validation Acc: 83.68
# Epoch: [4/10], Step: [625/625], Validation Acc: 84.66
# Epoch: [5/10], Step: [625/625], Validation Acc: 85.58
# Epoch: [6/10], Step: [625/625], Validation Acc: 85.24
# Epoch: [7/10], Step: [625/625], Validation Acc: 86.6
# Epoch: [8/10], Step: [625/625], Validation Acc: 86.46
# Epoch: [9/10], Step: [625/625], Validation Acc: 86.4
# Epoch: [10/10], Step: [625/625], Validation Acc: 87.0
# 85.44
#
# Now it is 27 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 81.8
# Epoch: [2/10], Step: [625/625], Validation Acc: 85.02
# Epoch: [3/10], Step: [625/625], Validation Acc: 86.36
# Epoch: [4/10], Step: [625/625], Validation Acc: 86.9
# Epoch: [5/10], Step: [625/625], Validation Acc: 86.78
# Epoch: [6/10], Step: [625/625], Validation Acc: 86.74
# Epoch: [7/10], Step: [625/625], Validation Acc: 86.32
# Epoch: [8/10], Step: [625/625], Validation Acc: 86.3
# Epoch: [9/10], Step: [625/625], Validation Acc: 85.84
# Epoch: [10/10], Step: [625/625], Validation Acc: 85.36
# 83.2
#
# Now it is 28 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 82.48
# Epoch: [2/10], Step: [625/625], Validation Acc: 85.14
# Epoch: [3/10], Step: [625/625], Validation Acc: 84.88
# Epoch: [4/10], Step: [625/625], Validation Acc: 87.12
# Epoch: [5/10], Step: [625/625], Validation Acc: 86.7
# Epoch: [6/10], Step: [625/625], Validation Acc: 86.84
# Epoch: [7/10], Step: [625/625], Validation Acc: 86.46
# Epoch: [8/10], Step: [625/625], Validation Acc: 86.64
# Epoch: [9/10], Step: [625/625], Validation Acc: 86.48
# Epoch: [10/10], Step: [625/625], Validation Acc: 86.28
# 84.248
#
# Now it is 29 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 86.38
# Epoch: [2/10], Step: [625/625], Validation Acc: 86.26
# Epoch: [3/10], Step: [625/625], Validation Acc: 85.18
# Epoch: [4/10], Step: [625/625], Validation Acc: 84.6
# Epoch: [5/10], Step: [625/625], Validation Acc: 84.44
# Epoch: [6/10], Step: [625/625], Validation Acc: 83.7
# Epoch: [7/10], Step: [625/625], Validation Acc: 83.72
# Epoch: [8/10], Step: [625/625], Validation Acc: 83.34
# Epoch: [9/10], Step: [625/625], Validation Acc: 83.04
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.12
# 80.452
#
# Now it is 30 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 86.5
# Epoch: [2/10], Step: [625/625], Validation Acc: 86.38
# Epoch: [3/10], Step: [625/625], Validation Acc: 85.78
# Epoch: [4/10], Step: [625/625], Validation Acc: 85.46
# Epoch: [5/10], Step: [625/625], Validation Acc: 84.98
# Epoch: [6/10], Step: [625/625], Validation Acc: 84.34
# Epoch: [7/10], Step: [625/625], Validation Acc: 84.2
# Epoch: [8/10], Step: [625/625], Validation Acc: 84.1
# Epoch: [9/10], Step: [625/625], Validation Acc: 83.3
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.24
# 80.212

# %% [markdown]
# # ngram = 2, max_vocab_size = 10000

# %%
grid = {'emb_dim':[100,200,300,400,500],'optimizer':['Adam','RMSprop'], 'learning_rate': [0.0005,0.001,0.005]}
num_comb = len(ParameterGrid(grid))
count = 0

for j in range(len(ParameterGrid(grid))):
    count += 1
    print("Now it is {} out of {} combinations".format(count, num_comb))
    optimizer,learning_rate, emb_dim = ParameterGrid(grid)[j].values()
    myCsvRow = "optimizer = {}, learning_rate = {}, emb_dim = {}".format(optimizer, learning_rate, emb_dim)
    print(myCsvRow)
    tuning(emb_dim, optimizer, learning_rate)
    print()
# Out:
# Now it is 1 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 58.22
# Epoch: [2/10], Step: [625/625], Validation Acc: 66.28
# Epoch: [3/10], Step: [625/625], Validation Acc: 77.48
# Epoch: [4/10], Step: [625/625], Validation Acc: 79.1
# Epoch: [5/10], Step: [625/625], Validation Acc: 80.36
# Epoch: [6/10], Step: [625/625], Validation Acc: 81.46
# Epoch: [7/10], Step: [625/625], Validation Acc: 81.96
# Epoch: [8/10], Step: [625/625], Validation Acc: 82.36
# Epoch: [9/10], Step: [625/625], Validation Acc: 81.98
# Epoch: [10/10], Step: [625/625], Validation Acc: 82.56
# 82.844
#
# Now it is 2 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 65.48
# Epoch: [2/10], Step: [625/625], Validation Acc: 71.54
# Epoch: [3/10], Step: [625/625], Validation Acc: 75.66
# Epoch: [4/10], Step: [625/625], Validation Acc: 77.74
# Epoch: [5/10], Step: [625/625], Validation Acc: 78.6
# Epoch: [6/10], Step: [625/625], Validation Acc: 80.64
# Epoch: [7/10], Step: [625/625], Validation Acc: 80.72
# Epoch: [8/10], Step: [625/625], Validation Acc: 81.92
# Epoch: [9/10], Step: [625/625], Validation Acc: 82.42
# Epoch: [10/10], Step: [625/625], Validation Acc: 82.36
# 82.948
#
# Now it is 3 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 72.2
# Epoch: [2/10], Step: [625/625], Validation Acc: 76.9
# Epoch: [3/10], Step: [625/625], Validation Acc: 80.94
# Epoch: [4/10], Step: [625/625], Validation Acc: 82.0
# Epoch: [5/10], Step: [625/625], Validation Acc: 82.74
# Epoch: [6/10], Step: [625/625], Validation Acc: 83.32
# Epoch: [7/10], Step: [625/625], Validation Acc: 83.4
# Epoch: [8/10], Step: [625/625], Validation Acc: 82.82
# Epoch: [9/10], Step: [625/625], Validation Acc: 83.46
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.3
# 83.792
#
# Now it is 4 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 62.22
# Epoch: [2/10], Step: [625/625], Validation Acc: 75.64
# Epoch: [3/10], Step: [625/625], Validation Acc: 79.36
# Epoch: [4/10], Step: [625/625], Validation Acc: 81.82
# Epoch: [5/10], Step: [625/625], Validation Acc: 81.06
# Epoch: [6/10], Step: [625/625], Validation Acc: 82.66
# Epoch: [7/10], Step: [625/625], Validation Acc: 82.98
# Epoch: [8/10], Step: [625/625], Validation Acc: 83.14
# Epoch: [9/10], Step: [625/625], Validation Acc: 83.62
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.4
# 83.96
#
# Now it is 5 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 82.38
# Epoch: [2/10], Step: [625/625], Validation Acc: 82.72
# Epoch: [3/10], Step: [625/625], Validation Acc: 82.52
# Epoch: [4/10], Step: [625/625], Validation Acc: 81.46
# Epoch: [5/10], Step: [625/625], Validation Acc: 80.46
# Epoch: [6/10], Step: [625/625], Validation Acc: 80.82
# Epoch: [7/10], Step: [625/625], Validation Acc: 80.2
# Epoch: [8/10], Step: [625/625], Validation Acc: 79.84
# Epoch: [9/10], Step: [625/625], Validation Acc: 79.48
# Epoch: [10/10], Step: [625/625], Validation Acc: 79.14
# 80.288
#
# Now it is 6 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 82.7
# Epoch: [2/10], Step: [625/625], Validation Acc: 82.72
# Epoch: [3/10], Step: [625/625], Validation Acc: 82.06
# Epoch: [4/10], Step: [625/625], Validation Acc: 82.24
# Epoch: [5/10], Step: [625/625], Validation Acc: 80.92
# Epoch: [6/10], Step: [625/625], Validation Acc: 80.52
# Epoch: [7/10], Step: [625/625], Validation Acc: 80.7
# Epoch: [8/10], Step: [625/625], Validation Acc: 79.78
# Epoch: [9/10], Step: [625/625], Validation Acc: 79.92
# Epoch: [10/10], Step: [625/625], Validation Acc: 79.9
# 80.84
#
# Now it is 7 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 71.9
# Epoch: [2/10], Step: [625/625], Validation Acc: 74.48
# Epoch: [3/10], Step: [625/625], Validation Acc: 79.12
# Epoch: [4/10], Step: [625/625], Validation Acc: 80.48
# Epoch: [5/10], Step: [625/625], Validation Acc: 81.2
# Epoch: [6/10], Step: [625/625], Validation Acc: 82.5
# Epoch: [7/10], Step: [625/625], Validation Acc: 82.62
# Epoch: [8/10], Step: [625/625], Validation Acc: 83.02
# Epoch: [9/10], Step: [625/625], Validation Acc: 83.32
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.24
# 83.42
#
# Now it is 8 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 57.18
# Epoch: [2/10], Step: [625/625], Validation Acc: 70.6
# Epoch: [3/10], Step: [625/625], Validation Acc: 78.4
# Epoch: [4/10], Step: [625/625], Validation Acc: 79.02
# Epoch: [5/10], Step: [625/625], Validation Acc: 81.32
# Epoch: [6/10], Step: [625/625], Validation Acc: 81.06
# Epoch: [7/10], Step: [625/625], Validation Acc: 82.36
# Epoch: [8/10], Step: [625/625], Validation Acc: 82.2
# Epoch: [9/10], Step: [625/625], Validation Acc: 82.56
# Epoch: [10/10], Step: [625/625], Validation Acc: 82.94
# 83.7
#
# Now it is 9 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 75.74
# Epoch: [2/10], Step: [625/625], Validation Acc: 80.5
# Epoch: [3/10], Step: [625/625], Validation Acc: 82.16
# Epoch: [4/10], Step: [625/625], Validation Acc: 81.3
# Epoch: [5/10], Step: [625/625], Validation Acc: 82.4
# Epoch: [6/10], Step: [625/625], Validation Acc: 82.92
# Epoch: [7/10], Step: [625/625], Validation Acc: 83.22
# Epoch: [8/10], Step: [625/625], Validation Acc: 83.12
# Epoch: [9/10], Step: [625/625], Validation Acc: 82.8
# Epoch: [10/10], Step: [625/625], Validation Acc: 82.84
# 83.12
#
# Now it is 10 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 75.46
# Epoch: [2/10], Step: [625/625], Validation Acc: 79.44
# Epoch: [3/10], Step: [625/625], Validation Acc: 81.28
# Epoch: [4/10], Step: [625/625], Validation Acc: 82.58
# Epoch: [5/10], Step: [625/625], Validation Acc: 81.96
# Epoch: [6/10], Step: [625/625], Validation Acc: 83.18
# Epoch: [7/10], Step: [625/625], Validation Acc: 83.32
# Epoch: [8/10], Step: [625/625], Validation Acc: 83.3
# Epoch: [9/10], Step: [625/625], Validation Acc: 83.18
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.06
# 83.42
#
# Now it is 11 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 81.78
# Epoch: [2/10], Step: [625/625], Validation Acc: 82.5
# Epoch: [3/10], Step: [625/625], Validation Acc: 81.0
# Epoch: [4/10], Step: [625/625], Validation Acc: 81.26
# Epoch: [5/10], Step: [625/625], Validation Acc: 80.6
# Epoch: [6/10], Step: [625/625], Validation Acc: 79.96
# Epoch: [7/10], Step: [625/625], Validation Acc: 79.46
# Epoch: [8/10], Step: [625/625], Validation Acc: 78.78
# Epoch: [9/10], Step: [625/625], Validation Acc: 78.7
# Epoch: [10/10], Step: [625/625], Validation Acc: 78.68
# 79.752
#
# Now it is 12 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 75.8
# Epoch: [2/10], Step: [625/625], Validation Acc: 82.48
# Epoch: [3/10], Step: [625/625], Validation Acc: 82.26
# Epoch: [4/10], Step: [625/625], Validation Acc: 81.14
# Epoch: [5/10], Step: [625/625], Validation Acc: 81.02
# Epoch: [6/10], Step: [625/625], Validation Acc: 80.8
# Epoch: [7/10], Step: [625/625], Validation Acc: 80.28
# Epoch: [8/10], Step: [625/625], Validation Acc: 79.68
# Epoch: [9/10], Step: [625/625], Validation Acc: 79.28
# Epoch: [10/10], Step: [625/625], Validation Acc: 79.3
# 80.376
#
# Now it is 13 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 60.66
# Epoch: [2/10], Step: [625/625], Validation Acc: 77.4
# Epoch: [3/10], Step: [625/625], Validation Acc: 78.8
# Epoch: [4/10], Step: [625/625], Validation Acc: 79.5
# Epoch: [5/10], Step: [625/625], Validation Acc: 82.06
# Epoch: [6/10], Step: [625/625], Validation Acc: 82.04
# Epoch: [7/10], Step: [625/625], Validation Acc: 81.94
# Epoch: [8/10], Step: [625/625], Validation Acc: 82.7
# Epoch: [9/10], Step: [625/625], Validation Acc: 82.44
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.1
# 83.616
#
# Now it is 14 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 61.6
# Epoch: [2/10], Step: [625/625], Validation Acc: 76.28
# Epoch: [3/10], Step: [625/625], Validation Acc: 79.4
# Epoch: [4/10], Step: [625/625], Validation Acc: 80.54
# Epoch: [5/10], Step: [625/625], Validation Acc: 81.88
# Epoch: [6/10], Step: [625/625], Validation Acc: 81.16
# Epoch: [7/10], Step: [625/625], Validation Acc: 82.94
# Epoch: [8/10], Step: [625/625], Validation Acc: 83.22
# Epoch: [9/10], Step: [625/625], Validation Acc: 83.2
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.2
# 83.628
#
# Now it is 15 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 77.38
# Epoch: [2/10], Step: [625/625], Validation Acc: 80.02
# Epoch: [3/10], Step: [625/625], Validation Acc: 82.46
# Epoch: [4/10], Step: [625/625], Validation Acc: 82.64
# Epoch: [5/10], Step: [625/625], Validation Acc: 83.08
# Epoch: [6/10], Step: [625/625], Validation Acc: 82.14
# Epoch: [7/10], Step: [625/625], Validation Acc: 82.32
# Epoch: [8/10], Step: [625/625], Validation Acc: 82.72
# Epoch: [9/10], Step: [625/625], Validation Acc: 82.3
# Epoch: [10/10], Step: [625/625], Validation Acc: 81.44
# 81.732
#
# Now it is 16 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 70.56
# Epoch: [2/10], Step: [625/625], Validation Acc: 81.24
# Epoch: [3/10], Step: [625/625], Validation Acc: 82.28
# Epoch: [4/10], Step: [625/625], Validation Acc: 82.12
# Epoch: [5/10], Step: [625/625], Validation Acc: 82.56
# Epoch: [6/10], Step: [625/625], Validation Acc: 82.86
# Epoch: [7/10], Step: [625/625], Validation Acc: 82.7
# Epoch: [8/10], Step: [625/625], Validation Acc: 82.06
# Epoch: [9/10], Step: [625/625], Validation Acc: 82.78
# Epoch: [10/10], Step: [625/625], Validation Acc: 82.86
# 83.2
#
# Now it is 17 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 82.46
# Epoch: [2/10], Step: [625/625], Validation Acc: 82.42
# Epoch: [3/10], Step: [625/625], Validation Acc: 81.58
# Epoch: [4/10], Step: [625/625], Validation Acc: 80.52
# Epoch: [5/10], Step: [625/625], Validation Acc: 80.4
# Epoch: [6/10], Step: [625/625], Validation Acc: 80.26
# Epoch: [7/10], Step: [625/625], Validation Acc: 79.04
# Epoch: [8/10], Step: [625/625], Validation Acc: 78.74
# Epoch: [9/10], Step: [625/625], Validation Acc: 78.66
# Epoch: [10/10], Step: [625/625], Validation Acc: 78.32
# 79.48
#
# Now it is 18 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 79.72
# Epoch: [2/10], Step: [625/625], Validation Acc: 82.8
# Epoch: [3/10], Step: [625/625], Validation Acc: 81.04
# Epoch: [4/10], Step: [625/625], Validation Acc: 79.28
# Epoch: [5/10], Step: [625/625], Validation Acc: 80.8
# Epoch: [6/10], Step: [625/625], Validation Acc: 80.4
# Epoch: [7/10], Step: [625/625], Validation Acc: 79.56
# Epoch: [8/10], Step: [625/625], Validation Acc: 79.92
# Epoch: [9/10], Step: [625/625], Validation Acc: 79.52
# Epoch: [10/10], Step: [625/625], Validation Acc: 79.44
# 79.956
#
# Now it is 19 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 72.08
# Epoch: [2/10], Step: [625/625], Validation Acc: 78.62
# Epoch: [3/10], Step: [625/625], Validation Acc: 80.72
# Epoch: [4/10], Step: [625/625], Validation Acc: 82.1
# Epoch: [5/10], Step: [625/625], Validation Acc: 82.62
# Epoch: [6/10], Step: [625/625], Validation Acc: 83.12
# Epoch: [7/10], Step: [625/625], Validation Acc: 83.28
# Epoch: [8/10], Step: [625/625], Validation Acc: 83.52
# Epoch: [9/10], Step: [625/625], Validation Acc: 83.48
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.22
# 83.628
#
# Now it is 20 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 63.52
# Epoch: [2/10], Step: [625/625], Validation Acc: 78.04
# Epoch: [3/10], Step: [625/625], Validation Acc: 77.38
# Epoch: [4/10], Step: [625/625], Validation Acc: 80.6
# Epoch: [5/10], Step: [625/625], Validation Acc: 81.94
# Epoch: [6/10], Step: [625/625], Validation Acc: 81.62
# Epoch: [7/10], Step: [625/625], Validation Acc: 82.96
# Epoch: [8/10], Step: [625/625], Validation Acc: 82.74
# Epoch: [9/10], Step: [625/625], Validation Acc: 82.58
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.06
# 83.44
#
# Now it is 21 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 77.58
# Epoch: [2/10], Step: [625/625], Validation Acc: 80.9
# Epoch: [3/10], Step: [625/625], Validation Acc: 83.0
# Epoch: [4/10], Step: [625/625], Validation Acc: 83.34
# Epoch: [5/10], Step: [625/625], Validation Acc: 81.08
# Epoch: [6/10], Step: [625/625], Validation Acc: 82.9
# Epoch: [7/10], Step: [625/625], Validation Acc: 82.7
# Epoch: [8/10], Step: [625/625], Validation Acc: 82.52
# Epoch: [9/10], Step: [625/625], Validation Acc: 82.28
# Epoch: [10/10], Step: [625/625], Validation Acc: 82.02
# 82.392
#
# Now it is 22 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 76.78
# Epoch: [2/10], Step: [625/625], Validation Acc: 81.32
# Epoch: [3/10], Step: [625/625], Validation Acc: 82.9
# Epoch: [4/10], Step: [625/625], Validation Acc: 83.12
# Epoch: [5/10], Step: [625/625], Validation Acc: 82.28
# Epoch: [6/10], Step: [625/625], Validation Acc: 83.0
# Epoch: [7/10], Step: [625/625], Validation Acc: 82.28
# Epoch: [8/10], Step: [625/625], Validation Acc: 82.74
# Epoch: [9/10], Step: [625/625], Validation Acc: 82.52
# Epoch: [10/10], Step: [625/625], Validation Acc: 82.18
# 82.988
#
# Now it is 23 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 82.74
# Epoch: [2/10], Step: [625/625], Validation Acc: 82.52
# Epoch: [3/10], Step: [625/625], Validation Acc: 81.54
# Epoch: [4/10], Step: [625/625], Validation Acc: 80.56
# Epoch: [5/10], Step: [625/625], Validation Acc: 79.58
# Epoch: [6/10], Step: [625/625], Validation Acc: 79.72
# Epoch: [7/10], Step: [625/625], Validation Acc: 79.08
# Epoch: [8/10], Step: [625/625], Validation Acc: 78.98
# Epoch: [9/10], Step: [625/625], Validation Acc: 78.56
# Epoch: [10/10], Step: [625/625], Validation Acc: 78.06
# 79.644
#
# Now it is 24 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 80.36
# Epoch: [2/10], Step: [625/625], Validation Acc: 83.0
# Epoch: [3/10], Step: [625/625], Validation Acc: 81.94
# Epoch: [4/10], Step: [625/625], Validation Acc: 81.46
# Epoch: [5/10], Step: [625/625], Validation Acc: 80.46
# Epoch: [6/10], Step: [625/625], Validation Acc: 80.62
# Epoch: [7/10], Step: [625/625], Validation Acc: 79.76
# Epoch: [8/10], Step: [625/625], Validation Acc: 79.58
# Epoch: [9/10], Step: [625/625], Validation Acc: 79.1
# Epoch: [10/10], Step: [625/625], Validation Acc: 79.1
# 79.912
#
# Now it is 25 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 65.1
# Epoch: [2/10], Step: [625/625], Validation Acc: 78.24
# Epoch: [3/10], Step: [625/625], Validation Acc: 80.3
# Epoch: [4/10], Step: [625/625], Validation Acc: 81.5
# Epoch: [5/10], Step: [625/625], Validation Acc: 80.0
# Epoch: [6/10], Step: [625/625], Validation Acc: 83.02
# Epoch: [7/10], Step: [625/625], Validation Acc: 83.06
# Epoch: [8/10], Step: [625/625], Validation Acc: 83.26
# Epoch: [9/10], Step: [625/625], Validation Acc: 83.4
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.32
# 83.56
#
# Now it is 26 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 69.82
# Epoch: [2/10], Step: [625/625], Validation Acc: 78.22
# Epoch: [3/10], Step: [625/625], Validation Acc: 80.24
# Epoch: [4/10], Step: [625/625], Validation Acc: 81.26
# Epoch: [5/10], Step: [625/625], Validation Acc: 82.18
# Epoch: [6/10], Step: [625/625], Validation Acc: 82.74
# Epoch: [7/10], Step: [625/625], Validation Acc: 83.06
# Epoch: [8/10], Step: [625/625], Validation Acc: 82.98
# Epoch: [9/10], Step: [625/625], Validation Acc: 83.24
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.1
# 83.656
#
# Now it is 27 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 77.78
# Epoch: [2/10], Step: [625/625], Validation Acc: 82.26
# Epoch: [3/10], Step: [625/625], Validation Acc: 81.88
# Epoch: [4/10], Step: [625/625], Validation Acc: 83.38
# Epoch: [5/10], Step: [625/625], Validation Acc: 83.02
# Epoch: [6/10], Step: [625/625], Validation Acc: 82.42
# Epoch: [7/10], Step: [625/625], Validation Acc: 82.22
# Epoch: [8/10], Step: [625/625], Validation Acc: 81.74
# Epoch: [9/10], Step: [625/625], Validation Acc: 81.42
# Epoch: [10/10], Step: [625/625], Validation Acc: 81.46
# 82.404
#
# Now it is 28 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 71.66
# Epoch: [2/10], Step: [625/625], Validation Acc: 81.34
# Epoch: [3/10], Step: [625/625], Validation Acc: 82.8
# Epoch: [4/10], Step: [625/625], Validation Acc: 82.1
# Epoch: [5/10], Step: [625/625], Validation Acc: 83.34
# Epoch: [6/10], Step: [625/625], Validation Acc: 83.26
# Epoch: [7/10], Step: [625/625], Validation Acc: 82.66
# Epoch: [8/10], Step: [625/625], Validation Acc: 81.66
# Epoch: [9/10], Step: [625/625], Validation Acc: 82.5
# Epoch: [10/10], Step: [625/625], Validation Acc: 82.24
# 82.908
#
# Now it is 29 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 80.26
# Epoch: [2/10], Step: [625/625], Validation Acc: 82.62
# Epoch: [3/10], Step: [625/625], Validation Acc: 80.06
# Epoch: [4/10], Step: [625/625], Validation Acc: 80.6
# Epoch: [5/10], Step: [625/625], Validation Acc: 79.58
# Epoch: [6/10], Step: [625/625], Validation Acc: 79.76
# Epoch: [7/10], Step: [625/625], Validation Acc: 79.3
# Epoch: [8/10], Step: [625/625], Validation Acc: 79.24
# Epoch: [9/10], Step: [625/625], Validation Acc: 78.68
# Epoch: [10/10], Step: [625/625], Validation Acc: 78.16
# 79.268
#
# Now it is 30 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 81.2
# Epoch: [2/10], Step: [625/625], Validation Acc: 76.88
# Epoch: [3/10], Step: [625/625], Validation Acc: 81.9
# Epoch: [4/10], Step: [625/625], Validation Acc: 80.92
# Epoch: [5/10], Step: [625/625], Validation Acc: 80.54
# Epoch: [6/10], Step: [625/625], Validation Acc: 80.14
# Epoch: [7/10], Step: [625/625], Validation Acc: 80.1
# Epoch: [8/10], Step: [625/625], Validation Acc: 79.06
# Epoch: [9/10], Step: [625/625], Validation Acc: 79.08
# Epoch: [10/10], Step: [625/625], Validation Acc: 78.74
# 79.836

# %% [markdown]
# # ngram = 3, max_vocab_size = 10000

# %%
grid = {'emb_dim':[100,200,300,400,500],'optimizer':['Adam','RMSprop'], 'learning_rate': [0.0005,0.001,0.005]}
num_comb = len(ParameterGrid(grid))
count = 0

for j in range(len(ParameterGrid(grid))):
    count += 1
    print("Now it is {} out of {} combinations".format(count, num_comb))
    optimizer,learning_rate, emb_dim = ParameterGrid(grid)[j].values()
    myCsvRow = "optimizer = {}, learning_rate = {}, emb_dim = {}".format(optimizer, learning_rate, emb_dim)
    print(myCsvRow)
    tuning(emb_dim, optimizer, learning_rate)
    print()
# Out:
# Now it is 1 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 54.5
# Epoch: [2/10], Step: [625/625], Validation Acc: 56.42
# Epoch: [3/10], Step: [625/625], Validation Acc: 59.48
# Epoch: [4/10], Step: [625/625], Validation Acc: 66.72
# Epoch: [5/10], Step: [625/625], Validation Acc: 74.6
# Epoch: [6/10], Step: [625/625], Validation Acc: 74.1
# Epoch: [7/10], Step: [625/625], Validation Acc: 71.0
# Epoch: [8/10], Step: [625/625], Validation Acc: 75.66
# Epoch: [9/10], Step: [625/625], Validation Acc: 75.88
# Epoch: [10/10], Step: [625/625], Validation Acc: 76.08
# 76.692
#
# Now it is 2 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 49.74
# Epoch: [2/10], Step: [625/625], Validation Acc: 68.54
# Epoch: [3/10], Step: [625/625], Validation Acc: 65.78
# Epoch: [4/10], Step: [625/625], Validation Acc: 71.32
# Epoch: [5/10], Step: [625/625], Validation Acc: 71.52
# Epoch: [6/10], Step: [625/625], Validation Acc: 72.24
# Epoch: [7/10], Step: [625/625], Validation Acc: 74.18
# Epoch: [8/10], Step: [625/625], Validation Acc: 72.34
# Epoch: [9/10], Step: [625/625], Validation Acc: 75.64
# Epoch: [10/10], Step: [625/625], Validation Acc: 76.3
# 76.612
#
# Now it is 3 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 49.76
# Epoch: [2/10], Step: [625/625], Validation Acc: 63.8
# Epoch: [3/10], Step: [625/625], Validation Acc: 74.44
# Epoch: [4/10], Step: [625/625], Validation Acc: 75.98
# Epoch: [5/10], Step: [625/625], Validation Acc: 69.86
# Epoch: [6/10], Step: [625/625], Validation Acc: 76.46
# Epoch: [7/10], Step: [625/625], Validation Acc: 77.38
# Epoch: [8/10], Step: [625/625], Validation Acc: 76.64
# Epoch: [9/10], Step: [625/625], Validation Acc: 77.4
# Epoch: [10/10], Step: [625/625], Validation Acc: 77.48
# 78.112
#
# Now it is 4 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 52.26
# Epoch: [2/10], Step: [625/625], Validation Acc: 69.9
# Epoch: [3/10], Step: [625/625], Validation Acc: 72.88
# Epoch: [4/10], Step: [625/625], Validation Acc: 74.62
# Epoch: [5/10], Step: [625/625], Validation Acc: 75.7
# Epoch: [6/10], Step: [625/625], Validation Acc: 76.54
# Epoch: [7/10], Step: [625/625], Validation Acc: 76.2
# Epoch: [8/10], Step: [625/625], Validation Acc: 75.08
# Epoch: [9/10], Step: [625/625], Validation Acc: 77.6
# Epoch: [10/10], Step: [625/625], Validation Acc: 77.88
# 78.272
#
# Now it is 5 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 74.1
# Epoch: [2/10], Step: [625/625], Validation Acc: 75.76
# Epoch: [3/10], Step: [625/625], Validation Acc: 76.32
# Epoch: [4/10], Step: [625/625], Validation Acc: 75.16
# Epoch: [5/10], Step: [625/625], Validation Acc: 76.52
# Epoch: [6/10], Step: [625/625], Validation Acc: 76.5
# Epoch: [7/10], Step: [625/625], Validation Acc: 75.72
# Epoch: [8/10], Step: [625/625], Validation Acc: 74.5
# Epoch: [9/10], Step: [625/625], Validation Acc: 75.08
# Epoch: [10/10], Step: [625/625], Validation Acc: 75.04
# 75.784
#
# Now it is 6 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 75.64
# Epoch: [2/10], Step: [625/625], Validation Acc: 77.12
# Epoch: [3/10], Step: [625/625], Validation Acc: 77.38
# Epoch: [4/10], Step: [625/625], Validation Acc: 77.06
# Epoch: [5/10], Step: [625/625], Validation Acc: 75.5
# Epoch: [6/10], Step: [625/625], Validation Acc: 76.16
# Epoch: [7/10], Step: [625/625], Validation Acc: 73.66
# Epoch: [8/10], Step: [625/625], Validation Acc: 75.02
# Epoch: [9/10], Step: [625/625], Validation Acc: 75.9
# Epoch: [10/10], Step: [625/625], Validation Acc: 74.26
# 74.66
#
# Now it is 7 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 61.3
# Epoch: [2/10], Step: [625/625], Validation Acc: 64.5
# Epoch: [3/10], Step: [625/625], Validation Acc: 65.62
# Epoch: [4/10], Step: [625/625], Validation Acc: 74.12
# Epoch: [5/10], Step: [625/625], Validation Acc: 74.22
# Epoch: [6/10], Step: [625/625], Validation Acc: 75.1
# Epoch: [7/10], Step: [625/625], Validation Acc: 75.64
# Epoch: [8/10], Step: [625/625], Validation Acc: 75.96
# Epoch: [9/10], Step: [625/625], Validation Acc: 76.34
# Epoch: [10/10], Step: [625/625], Validation Acc: 75.66
# 76.992
#
# Now it is 8 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 49.72
# Epoch: [2/10], Step: [625/625], Validation Acc: 49.98
# Epoch: [3/10], Step: [625/625], Validation Acc: 66.22
# Epoch: [4/10], Step: [625/625], Validation Acc: 71.68
# Epoch: [5/10], Step: [625/625], Validation Acc: 73.04
# Epoch: [6/10], Step: [625/625], Validation Acc: 74.52
# Epoch: [7/10], Step: [625/625], Validation Acc: 74.96
# Epoch: [8/10], Step: [625/625], Validation Acc: 75.62
# Epoch: [9/10], Step: [625/625], Validation Acc: 74.38
# Epoch: [10/10], Step: [625/625], Validation Acc: 74.66
# 75.816
#
# Now it is 9 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 51.84
# Epoch: [2/10], Step: [625/625], Validation Acc: 56.7
# Epoch: [3/10], Step: [625/625], Validation Acc: 75.06
# Epoch: [4/10], Step: [625/625], Validation Acc: 74.38
# Epoch: [5/10], Step: [625/625], Validation Acc: 74.86
# Epoch: [6/10], Step: [625/625], Validation Acc: 77.24
# Epoch: [7/10], Step: [625/625], Validation Acc: 77.36
# Epoch: [8/10], Step: [625/625], Validation Acc: 77.82
# Epoch: [9/10], Step: [625/625], Validation Acc: 77.7
# Epoch: [10/10], Step: [625/625], Validation Acc: 76.6
# 77.208
#
# Now it is 10 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 51.5
# Epoch: [2/10], Step: [625/625], Validation Acc: 61.6
# Epoch: [3/10], Step: [625/625], Validation Acc: 75.18
# Epoch: [4/10], Step: [625/625], Validation Acc: 76.28
# Epoch: [5/10], Step: [625/625], Validation Acc: 73.0
# Epoch: [6/10], Step: [625/625], Validation Acc: 74.36
# Epoch: [7/10], Step: [625/625], Validation Acc: 77.76
# Epoch: [8/10], Step: [625/625], Validation Acc: 78.1
# Epoch: [9/10], Step: [625/625], Validation Acc: 78.16
# Epoch: [10/10], Step: [625/625], Validation Acc: 78.12
# 78.708
#
# Now it is 11 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 70.0
# Epoch: [2/10], Step: [625/625], Validation Acc: 76.8
# Epoch: [3/10], Step: [625/625], Validation Acc: 76.82
# Epoch: [4/10], Step: [625/625], Validation Acc: 76.84
# Epoch: [5/10], Step: [625/625], Validation Acc: 75.98
# Epoch: [6/10], Step: [625/625], Validation Acc: 75.62
# Epoch: [7/10], Step: [625/625], Validation Acc: 75.78
# Epoch: [8/10], Step: [625/625], Validation Acc: 75.06
# Epoch: [9/10], Step: [625/625], Validation Acc: 75.08
# Epoch: [10/10], Step: [625/625], Validation Acc: 74.86
# 75.516
#
# Now it is 12 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 76.42
# Epoch: [2/10], Step: [625/625], Validation Acc: 76.92
# Epoch: [3/10], Step: [625/625], Validation Acc: 75.7
# Epoch: [4/10], Step: [625/625], Validation Acc: 77.3
# Epoch: [5/10], Step: [625/625], Validation Acc: 76.76
# Epoch: [6/10], Step: [625/625], Validation Acc: 76.12
# Epoch: [7/10], Step: [625/625], Validation Acc: 75.02
# Epoch: [8/10], Step: [625/625], Validation Acc: 76.5
# Epoch: [9/10], Step: [625/625], Validation Acc: 75.8
# Epoch: [10/10], Step: [625/625], Validation Acc: 75.34
# 76.06
#
# Now it is 13 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 64.6
# Epoch: [2/10], Step: [625/625], Validation Acc: 68.38
# Epoch: [3/10], Step: [625/625], Validation Acc: 72.14
# Epoch: [4/10], Step: [625/625], Validation Acc: 73.98
# Epoch: [5/10], Step: [625/625], Validation Acc: 74.1
# Epoch: [6/10], Step: [625/625], Validation Acc: 75.36
# Epoch: [7/10], Step: [625/625], Validation Acc: 76.28
# Epoch: [8/10], Step: [625/625], Validation Acc: 76.24
# Epoch: [9/10], Step: [625/625], Validation Acc: 75.6
# Epoch: [10/10], Step: [625/625], Validation Acc: 76.26
# 77.552
#
# Now it is 14 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 57.06
# Epoch: [2/10], Step: [625/625], Validation Acc: 53.1
# Epoch: [3/10], Step: [625/625], Validation Acc: 58.36
# Epoch: [4/10], Step: [625/625], Validation Acc: 74.08
# Epoch: [5/10], Step: [625/625], Validation Acc: 70.26
# Epoch: [6/10], Step: [625/625], Validation Acc: 76.14
# Epoch: [7/10], Step: [625/625], Validation Acc: 76.54
# Epoch: [8/10], Step: [625/625], Validation Acc: 73.84
# Epoch: [9/10], Step: [625/625], Validation Acc: 74.22
# Epoch: [10/10], Step: [625/625], Validation Acc: 75.8
# 76.704
#
# Now it is 15 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 49.74
# Epoch: [2/10], Step: [625/625], Validation Acc: 65.56
# Epoch: [3/10], Step: [625/625], Validation Acc: 71.58
# Epoch: [4/10], Step: [625/625], Validation Acc: 76.34
# Epoch: [5/10], Step: [625/625], Validation Acc: 76.56
# Epoch: [6/10], Step: [625/625], Validation Acc: 77.72
# Epoch: [7/10], Step: [625/625], Validation Acc: 76.08
# Epoch: [8/10], Step: [625/625], Validation Acc: 76.94
# Epoch: [9/10], Step: [625/625], Validation Acc: 77.16
# Epoch: [10/10], Step: [625/625], Validation Acc: 77.58
# 78.4
#
# Now it is 16 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 51.92
# Epoch: [2/10], Step: [625/625], Validation Acc: 70.34
# Epoch: [3/10], Step: [625/625], Validation Acc: 74.16
# Epoch: [4/10], Step: [625/625], Validation Acc: 76.48
# Epoch: [5/10], Step: [625/625], Validation Acc: 76.02
# Epoch: [6/10], Step: [625/625], Validation Acc: 75.58
# Epoch: [7/10], Step: [625/625], Validation Acc: 75.46
# Epoch: [8/10], Step: [625/625], Validation Acc: 76.82
# Epoch: [9/10], Step: [625/625], Validation Acc: 75.94
# Epoch: [10/10], Step: [625/625], Validation Acc: 77.68
# 78.576
#
# Now it is 17 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 77.32
# Epoch: [2/10], Step: [625/625], Validation Acc: 72.5
# Epoch: [3/10], Step: [625/625], Validation Acc: 77.46
# Epoch: [4/10], Step: [625/625], Validation Acc: 76.38
# Epoch: [5/10], Step: [625/625], Validation Acc: 76.78
# Epoch: [6/10], Step: [625/625], Validation Acc: 75.1
# Epoch: [7/10], Step: [625/625], Validation Acc: 75.48
# Epoch: [8/10], Step: [625/625], Validation Acc: 75.1
# Epoch: [9/10], Step: [625/625], Validation Acc: 74.64
# Epoch: [10/10], Step: [625/625], Validation Acc: 74.3
# 75.016
#
# Now it is 18 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 69.78
# Epoch: [2/10], Step: [625/625], Validation Acc: 75.78
# Epoch: [3/10], Step: [625/625], Validation Acc: 76.88
# Epoch: [4/10], Step: [625/625], Validation Acc: 75.24
# Epoch: [5/10], Step: [625/625], Validation Acc: 76.48
# Epoch: [6/10], Step: [625/625], Validation Acc: 75.82
# Epoch: [7/10], Step: [625/625], Validation Acc: 75.6
# Epoch: [8/10], Step: [625/625], Validation Acc: 75.56
# Epoch: [9/10], Step: [625/625], Validation Acc: 75.44
# Epoch: [10/10], Step: [625/625], Validation Acc: 75.18
# 76.16
#
# Now it is 19 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 49.7
# Epoch: [2/10], Step: [625/625], Validation Acc: 55.7
# Epoch: [3/10], Step: [625/625], Validation Acc: 61.22
# Epoch: [4/10], Step: [625/625], Validation Acc: 71.34
# Epoch: [5/10], Step: [625/625], Validation Acc: 73.02
# Epoch: [6/10], Step: [625/625], Validation Acc: 74.62
# Epoch: [7/10], Step: [625/625], Validation Acc: 75.4
# Epoch: [8/10], Step: [625/625], Validation Acc: 77.36
# Epoch: [9/10], Step: [625/625], Validation Acc: 76.74
# Epoch: [10/10], Step: [625/625], Validation Acc: 77.62
# 78.364
#
# Now it is 20 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 50.48
# Epoch: [2/10], Step: [625/625], Validation Acc: 66.56
# Epoch: [3/10], Step: [625/625], Validation Acc: 66.86
# Epoch: [4/10], Step: [625/625], Validation Acc: 73.12
# Epoch: [5/10], Step: [625/625], Validation Acc: 70.78
# Epoch: [6/10], Step: [625/625], Validation Acc: 74.62
# Epoch: [7/10], Step: [625/625], Validation Acc: 76.56
# Epoch: [8/10], Step: [625/625], Validation Acc: 75.68
# Epoch: [9/10], Step: [625/625], Validation Acc: 76.66
# Epoch: [10/10], Step: [625/625], Validation Acc: 77.14
# 77.948
#
# Now it is 21 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 51.74
# Epoch: [2/10], Step: [625/625], Validation Acc: 73.88
# Epoch: [3/10], Step: [625/625], Validation Acc: 74.88
# Epoch: [4/10], Step: [625/625], Validation Acc: 77.12
# Epoch: [5/10], Step: [625/625], Validation Acc: 77.54
# Epoch: [6/10], Step: [625/625], Validation Acc: 77.38
# Epoch: [7/10], Step: [625/625], Validation Acc: 77.18
# Epoch: [8/10], Step: [625/625], Validation Acc: 77.28
# Epoch: [9/10], Step: [625/625], Validation Acc: 76.5
# Epoch: [10/10], Step: [625/625], Validation Acc: 77.24
# 78.244
#
# Now it is 22 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 60.18
# Epoch: [2/10], Step: [625/625], Validation Acc: 73.82
# Epoch: [3/10], Step: [625/625], Validation Acc: 76.04
# Epoch: [4/10], Step: [625/625], Validation Acc: 76.62
# Epoch: [5/10], Step: [625/625], Validation Acc: 77.42
# Epoch: [6/10], Step: [625/625], Validation Acc: 73.0
# Epoch: [7/10], Step: [625/625], Validation Acc: 77.24
# Epoch: [8/10], Step: [625/625], Validation Acc: 77.68
# Epoch: [9/10], Step: [625/625], Validation Acc: 78.02
# Epoch: [10/10], Step: [625/625], Validation Acc: 77.1
# 78.2
#
# Now it is 23 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 77.3
# Epoch: [2/10], Step: [625/625], Validation Acc: 77.62
# Epoch: [3/10], Step: [625/625], Validation Acc: 76.58
# Epoch: [4/10], Step: [625/625], Validation Acc: 76.26
# Epoch: [5/10], Step: [625/625], Validation Acc: 75.9
# Epoch: [6/10], Step: [625/625], Validation Acc: 74.92
# Epoch: [7/10], Step: [625/625], Validation Acc: 74.1
# Epoch: [8/10], Step: [625/625], Validation Acc: 74.86
# Epoch: [9/10], Step: [625/625], Validation Acc: 74.58
# Epoch: [10/10], Step: [625/625], Validation Acc: 73.48
# 74.44
#
# Now it is 24 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 76.54
# Epoch: [2/10], Step: [625/625], Validation Acc: 73.22
# Epoch: [3/10], Step: [625/625], Validation Acc: 77.62
# Epoch: [4/10], Step: [625/625], Validation Acc: 76.26
# Epoch: [5/10], Step: [625/625], Validation Acc: 75.6
# Epoch: [6/10], Step: [625/625], Validation Acc: 76.54
# Epoch: [7/10], Step: [625/625], Validation Acc: 75.22
# Epoch: [8/10], Step: [625/625], Validation Acc: 75.9
# Epoch: [9/10], Step: [625/625], Validation Acc: 75.64
# Epoch: [10/10], Step: [625/625], Validation Acc: 75.56
# 76.22
#
# Now it is 25 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 50.24
# Epoch: [2/10], Step: [625/625], Validation Acc: 65.18
# Epoch: [3/10], Step: [625/625], Validation Acc: 68.84
# Epoch: [4/10], Step: [625/625], Validation Acc: 71.44
# Epoch: [5/10], Step: [625/625], Validation Acc: 72.76
# Epoch: [6/10], Step: [625/625], Validation Acc: 77.12
# Epoch: [7/10], Step: [625/625], Validation Acc: 75.7
# Epoch: [8/10], Step: [625/625], Validation Acc: 77.4
# Epoch: [9/10], Step: [625/625], Validation Acc: 77.6
# Epoch: [10/10], Step: [625/625], Validation Acc: 76.3
# 77.34
#
# Now it is 26 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 53.42
# Epoch: [2/10], Step: [625/625], Validation Acc: 58.12
# Epoch: [3/10], Step: [625/625], Validation Acc: 69.42
# Epoch: [4/10], Step: [625/625], Validation Acc: 73.36
# Epoch: [5/10], Step: [625/625], Validation Acc: 72.68
# Epoch: [6/10], Step: [625/625], Validation Acc: 75.96
# Epoch: [7/10], Step: [625/625], Validation Acc: 76.78
# Epoch: [8/10], Step: [625/625], Validation Acc: 77.04
# Epoch: [9/10], Step: [625/625], Validation Acc: 75.48
# Epoch: [10/10], Step: [625/625], Validation Acc: 77.92
# 78.32
#
# Now it is 27 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 51.02
# Epoch: [2/10], Step: [625/625], Validation Acc: 74.9
# Epoch: [3/10], Step: [625/625], Validation Acc: 75.92
# Epoch: [4/10], Step: [625/625], Validation Acc: 76.16
# Epoch: [5/10], Step: [625/625], Validation Acc: 75.54
# Epoch: [6/10], Step: [625/625], Validation Acc: 77.78
# Epoch: [7/10], Step: [625/625], Validation Acc: 76.74
# Epoch: [8/10], Step: [625/625], Validation Acc: 77.56
# Epoch: [9/10], Step: [625/625], Validation Acc: 77.18
# Epoch: [10/10], Step: [625/625], Validation Acc: 76.2
# 76.944
#
# Now it is 28 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 52.48
# Epoch: [2/10], Step: [625/625], Validation Acc: 68.14
# Epoch: [3/10], Step: [625/625], Validation Acc: 63.52
# Epoch: [4/10], Step: [625/625], Validation Acc: 71.36
# Epoch: [5/10], Step: [625/625], Validation Acc: 77.66
# Epoch: [6/10], Step: [625/625], Validation Acc: 77.22
# Epoch: [7/10], Step: [625/625], Validation Acc: 77.48
# Epoch: [8/10], Step: [625/625], Validation Acc: 77.62
# Epoch: [9/10], Step: [625/625], Validation Acc: 77.82
# Epoch: [10/10], Step: [625/625], Validation Acc: 77.28
# 77.84
#
# Now it is 29 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 74.42
# Epoch: [2/10], Step: [625/625], Validation Acc: 75.78
# Epoch: [3/10], Step: [625/625], Validation Acc: 76.26
# Epoch: [4/10], Step: [625/625], Validation Acc: 76.14
# Epoch: [5/10], Step: [625/625], Validation Acc: 76.4
# Epoch: [6/10], Step: [625/625], Validation Acc: 75.54
# Epoch: [7/10], Step: [625/625], Validation Acc: 74.32
# Epoch: [8/10], Step: [625/625], Validation Acc: 74.5
# Epoch: [9/10], Step: [625/625], Validation Acc: 73.64
# Epoch: [10/10], Step: [625/625], Validation Acc: 73.8
# 74.692
#
# Now it is 30 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 69.42
# Epoch: [2/10], Step: [625/625], Validation Acc: 75.06
# Epoch: [3/10], Step: [625/625], Validation Acc: 74.66
# Epoch: [4/10], Step: [625/625], Validation Acc: 76.02
# Epoch: [5/10], Step: [625/625], Validation Acc: 77.28
# Epoch: [6/10], Step: [625/625], Validation Acc: 73.26
# Epoch: [7/10], Step: [625/625], Validation Acc: 76.5
# Epoch: [8/10], Step: [625/625], Validation Acc: 73.22
# Epoch: [9/10], Step: [625/625], Validation Acc: 75.7
# Epoch: [10/10], Step: [625/625], Validation Acc: 75.18
# 75.784

# %% [markdown]
# # ngram = 3, max_vocab_size = 20000

# %%
grid = {'emb_dim':[100,200,300,400,500],'optimizer':['Adam','RMSprop'], 'learning_rate': [0.0005,0.001,0.005]}
num_comb = len(ParameterGrid(grid))
count = 0

for j in range(len(ParameterGrid(grid))):
    count += 1
    print("Now it is {} out of {} combinations".format(count, num_comb))
    optimizer,learning_rate, emb_dim = ParameterGrid(grid)[j].values()
    myCsvRow = "optimizer = {}, learning_rate = {}, emb_dim = {}".format(optimizer, learning_rate, emb_dim)
    print(myCsvRow)
    tuning(emb_dim, optimizer, learning_rate)
    print()
# Out:
# Now it is 1 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 56.4
# Epoch: [2/10], Step: [625/625], Validation Acc: 50.2
# Epoch: [3/10], Step: [625/625], Validation Acc: 61.06
# Epoch: [4/10], Step: [625/625], Validation Acc: 74.26
# Epoch: [5/10], Step: [625/625], Validation Acc: 74.16
# Epoch: [6/10], Step: [625/625], Validation Acc: 73.3
# Epoch: [7/10], Step: [625/625], Validation Acc: 76.82
# Epoch: [8/10], Step: [625/625], Validation Acc: 76.98
# Epoch: [9/10], Step: [625/625], Validation Acc: 76.5
# Epoch: [10/10], Step: [625/625], Validation Acc: 78.58
# 78.8
#
# Now it is 2 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 50.96
# Epoch: [2/10], Step: [625/625], Validation Acc: 68.86
# Epoch: [3/10], Step: [625/625], Validation Acc: 59.74
# Epoch: [4/10], Step: [625/625], Validation Acc: 73.56
# Epoch: [5/10], Step: [625/625], Validation Acc: 72.3
# Epoch: [6/10], Step: [625/625], Validation Acc: 74.66
# Epoch: [7/10], Step: [625/625], Validation Acc: 76.4
# Epoch: [8/10], Step: [625/625], Validation Acc: 72.8
# Epoch: [9/10], Step: [625/625], Validation Acc: 75.18
# Epoch: [10/10], Step: [625/625], Validation Acc: 75.78
# 76.208
#
# Now it is 3 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 56.38
# Epoch: [2/10], Step: [625/625], Validation Acc: 73.76
# Epoch: [3/10], Step: [625/625], Validation Acc: 75.44
# Epoch: [4/10], Step: [625/625], Validation Acc: 75.9
# Epoch: [5/10], Step: [625/625], Validation Acc: 78.22
# Epoch: [6/10], Step: [625/625], Validation Acc: 78.32
# Epoch: [7/10], Step: [625/625], Validation Acc: 78.94
# Epoch: [8/10], Step: [625/625], Validation Acc: 79.34
# Epoch: [9/10], Step: [625/625], Validation Acc: 79.26
# Epoch: [10/10], Step: [625/625], Validation Acc: 79.24
# 80.036
#
# Now it is 4 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 52.96
# Epoch: [2/10], Step: [625/625], Validation Acc: 69.74
# Epoch: [3/10], Step: [625/625], Validation Acc: 76.9
# Epoch: [4/10], Step: [625/625], Validation Acc: 77.78
# Epoch: [5/10], Step: [625/625], Validation Acc: 78.06
# Epoch: [6/10], Step: [625/625], Validation Acc: 77.88
# Epoch: [7/10], Step: [625/625], Validation Acc: 79.1
# Epoch: [8/10], Step: [625/625], Validation Acc: 78.34
# Epoch: [9/10], Step: [625/625], Validation Acc: 79.6
# Epoch: [10/10], Step: [625/625], Validation Acc: 79.7
# 80.06
#
# Now it is 5 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 77.82
# Epoch: [2/10], Step: [625/625], Validation Acc: 79.44
# Epoch: [3/10], Step: [625/625], Validation Acc: 79.54
# Epoch: [4/10], Step: [625/625], Validation Acc: 78.06
# Epoch: [5/10], Step: [625/625], Validation Acc: 78.78
# Epoch: [6/10], Step: [625/625], Validation Acc: 78.16
# Epoch: [7/10], Step: [625/625], Validation Acc: 77.42
# Epoch: [8/10], Step: [625/625], Validation Acc: 76.92
# Epoch: [9/10], Step: [625/625], Validation Acc: 77.42
# Epoch: [10/10], Step: [625/625], Validation Acc: 76.96
# 77.392
#
# Now it is 6 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 77.4
# Epoch: [2/10], Step: [625/625], Validation Acc: 79.44
# Epoch: [3/10], Step: [625/625], Validation Acc: 79.22
# Epoch: [4/10], Step: [625/625], Validation Acc: 78.84
# Epoch: [5/10], Step: [625/625], Validation Acc: 79.3
# Epoch: [6/10], Step: [625/625], Validation Acc: 78.76
# Epoch: [7/10], Step: [625/625], Validation Acc: 78.28
# Epoch: [8/10], Step: [625/625], Validation Acc: 77.9
# Epoch: [9/10], Step: [625/625], Validation Acc: 77.62
# Epoch: [10/10], Step: [625/625], Validation Acc: 77.58
# 78.076
#
# Now it is 7 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 52.86
# Epoch: [2/10], Step: [625/625], Validation Acc: 58.46
# Epoch: [3/10], Step: [625/625], Validation Acc: 69.7
# Epoch: [4/10], Step: [625/625], Validation Acc: 75.24
# Epoch: [5/10], Step: [625/625], Validation Acc: 74.7
# Epoch: [6/10], Step: [625/625], Validation Acc: 77.9
# Epoch: [7/10], Step: [625/625], Validation Acc: 77.72
# Epoch: [8/10], Step: [625/625], Validation Acc: 76.4
# Epoch: [9/10], Step: [625/625], Validation Acc: 78.28
# Epoch: [10/10], Step: [625/625], Validation Acc: 76.32
# 76.228
#
# Now it is 8 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 51.24
# Epoch: [2/10], Step: [625/625], Validation Acc: 59.32
# Epoch: [3/10], Step: [625/625], Validation Acc: 71.38
# Epoch: [4/10], Step: [625/625], Validation Acc: 62.46
# Epoch: [5/10], Step: [625/625], Validation Acc: 69.9
# Epoch: [6/10], Step: [625/625], Validation Acc: 74.52
# Epoch: [7/10], Step: [625/625], Validation Acc: 76.72
# Epoch: [8/10], Step: [625/625], Validation Acc: 77.24
# Epoch: [9/10], Step: [625/625], Validation Acc: 78.26
# Epoch: [10/10], Step: [625/625], Validation Acc: 78.56
# 79.224
#
# Now it is 9 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 55.78
# Epoch: [2/10], Step: [625/625], Validation Acc: 75.18
# Epoch: [3/10], Step: [625/625], Validation Acc: 76.28
# Epoch: [4/10], Step: [625/625], Validation Acc: 78.16
# Epoch: [5/10], Step: [625/625], Validation Acc: 78.48
# Epoch: [6/10], Step: [625/625], Validation Acc: 79.02
# Epoch: [7/10], Step: [625/625], Validation Acc: 79.34
# Epoch: [8/10], Step: [625/625], Validation Acc: 77.52
# Epoch: [9/10], Step: [625/625], Validation Acc: 79.3
# Epoch: [10/10], Step: [625/625], Validation Acc: 79.46
# 79.708
#
# Now it is 10 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 51.76
# Epoch: [2/10], Step: [625/625], Validation Acc: 69.4
# Epoch: [3/10], Step: [625/625], Validation Acc: 73.34
# Epoch: [4/10], Step: [625/625], Validation Acc: 77.12
# Epoch: [5/10], Step: [625/625], Validation Acc: 78.5
# Epoch: [6/10], Step: [625/625], Validation Acc: 79.2
# Epoch: [7/10], Step: [625/625], Validation Acc: 79.54
# Epoch: [8/10], Step: [625/625], Validation Acc: 76.68
# Epoch: [9/10], Step: [625/625], Validation Acc: 76.26
# Epoch: [10/10], Step: [625/625], Validation Acc: 78.6
# 79.292
#
# Now it is 11 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 78.92
# Epoch: [2/10], Step: [625/625], Validation Acc: 78.34
# Epoch: [3/10], Step: [625/625], Validation Acc: 78.28
# Epoch: [4/10], Step: [625/625], Validation Acc: 78.26
# Epoch: [5/10], Step: [625/625], Validation Acc: 77.82
# Epoch: [6/10], Step: [625/625], Validation Acc: 77.72
# Epoch: [7/10], Step: [625/625], Validation Acc: 77.34
# Epoch: [8/10], Step: [625/625], Validation Acc: 76.74
# Epoch: [9/10], Step: [625/625], Validation Acc: 76.76
# Epoch: [10/10], Step: [625/625], Validation Acc: 76.16
# 77.04
#
# Now it is 12 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 69.46
# Epoch: [2/10], Step: [625/625], Validation Acc: 79.0
# Epoch: [3/10], Step: [625/625], Validation Acc: 79.12
# Epoch: [4/10], Step: [625/625], Validation Acc: 78.66
# Epoch: [5/10], Step: [625/625], Validation Acc: 78.06
# Epoch: [6/10], Step: [625/625], Validation Acc: 69.78
# Epoch: [7/10], Step: [625/625], Validation Acc: 77.0
# Epoch: [8/10], Step: [625/625], Validation Acc: 77.62
# Epoch: [9/10], Step: [625/625], Validation Acc: 77.16
# Epoch: [10/10], Step: [625/625], Validation Acc: 75.32
# 75.456
#
# Now it is 13 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 59.8
# Epoch: [2/10], Step: [625/625], Validation Acc: 70.28
# Epoch: [3/10], Step: [625/625], Validation Acc: 74.62
# Epoch: [4/10], Step: [625/625], Validation Acc: 69.54
# Epoch: [5/10], Step: [625/625], Validation Acc: 77.46
# Epoch: [6/10], Step: [625/625], Validation Acc: 77.94
# Epoch: [7/10], Step: [625/625], Validation Acc: 78.64
# Epoch: [8/10], Step: [625/625], Validation Acc: 78.46
# Epoch: [9/10], Step: [625/625], Validation Acc: 78.08
# Epoch: [10/10], Step: [625/625], Validation Acc: 79.08
# 79.764
#
# Now it is 14 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 53.98
# Epoch: [2/10], Step: [625/625], Validation Acc: 71.8
# Epoch: [3/10], Step: [625/625], Validation Acc: 55.5
# Epoch: [4/10], Step: [625/625], Validation Acc: 73.18
# Epoch: [5/10], Step: [625/625], Validation Acc: 74.06
# Epoch: [6/10], Step: [625/625], Validation Acc: 76.86
# Epoch: [7/10], Step: [625/625], Validation Acc: 77.56
# Epoch: [8/10], Step: [625/625], Validation Acc: 76.68
# Epoch: [9/10], Step: [625/625], Validation Acc: 78.06
# Epoch: [10/10], Step: [625/625], Validation Acc: 79.08
# 79.464
#
# Now it is 15 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 51.78
# Epoch: [2/10], Step: [625/625], Validation Acc: 75.9
# Epoch: [3/10], Step: [625/625], Validation Acc: 75.44
# Epoch: [4/10], Step: [625/625], Validation Acc: 78.3
# Epoch: [5/10], Step: [625/625], Validation Acc: 79.14
# Epoch: [6/10], Step: [625/625], Validation Acc: 79.1
# Epoch: [7/10], Step: [625/625], Validation Acc: 78.88
# Epoch: [8/10], Step: [625/625], Validation Acc: 78.8
# Epoch: [9/10], Step: [625/625], Validation Acc: 79.28
# Epoch: [10/10], Step: [625/625], Validation Acc: 78.82
# 79.516
#
# Now it is 16 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 68.46
# Epoch: [2/10], Step: [625/625], Validation Acc: 64.64
# Epoch: [3/10], Step: [625/625], Validation Acc: 72.6
# Epoch: [4/10], Step: [625/625], Validation Acc: 78.1
# Epoch: [5/10], Step: [625/625], Validation Acc: 79.3
# Epoch: [6/10], Step: [625/625], Validation Acc: 76.6
# Epoch: [7/10], Step: [625/625], Validation Acc: 79.62
# Epoch: [8/10], Step: [625/625], Validation Acc: 79.86
# Epoch: [9/10], Step: [625/625], Validation Acc: 79.64
# Epoch: [10/10], Step: [625/625], Validation Acc: 77.16
# 77.476
#
# Now it is 17 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 78.56
# Epoch: [2/10], Step: [625/625], Validation Acc: 78.86
# Epoch: [3/10], Step: [625/625], Validation Acc: 78.16
# Epoch: [4/10], Step: [625/625], Validation Acc: 77.52
# Epoch: [5/10], Step: [625/625], Validation Acc: 76.92
# Epoch: [6/10], Step: [625/625], Validation Acc: 76.7
# Epoch: [7/10], Step: [625/625], Validation Acc: 75.7
# Epoch: [8/10], Step: [625/625], Validation Acc: 76.44
# Epoch: [9/10], Step: [625/625], Validation Acc: 76.54
# Epoch: [10/10], Step: [625/625], Validation Acc: 76.14
# 76.752
#
# Now it is 18 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 72.24
# Epoch: [2/10], Step: [625/625], Validation Acc: 78.14
# Epoch: [3/10], Step: [625/625], Validation Acc: 75.7
# Epoch: [4/10], Step: [625/625], Validation Acc: 76.72
# Epoch: [5/10], Step: [625/625], Validation Acc: 76.48
# Epoch: [6/10], Step: [625/625], Validation Acc: 76.58
# Epoch: [7/10], Step: [625/625], Validation Acc: 77.48
# Epoch: [8/10], Step: [625/625], Validation Acc: 77.5
# Epoch: [9/10], Step: [625/625], Validation Acc: 77.34
# Epoch: [10/10], Step: [625/625], Validation Acc: 76.9
# 76.78
#
# Now it is 19 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 49.7
# Epoch: [2/10], Step: [625/625], Validation Acc: 56.7
# Epoch: [3/10], Step: [625/625], Validation Acc: 75.74
# Epoch: [4/10], Step: [625/625], Validation Acc: 76.36
# Epoch: [5/10], Step: [625/625], Validation Acc: 75.68
# Epoch: [6/10], Step: [625/625], Validation Acc: 74.68
# Epoch: [7/10], Step: [625/625], Validation Acc: 78.4
# Epoch: [8/10], Step: [625/625], Validation Acc: 78.78
# Epoch: [9/10], Step: [625/625], Validation Acc: 79.12
# Epoch: [10/10], Step: [625/625], Validation Acc: 79.18
# 79.728
#
# Now it is 20 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 51.04
# Epoch: [2/10], Step: [625/625], Validation Acc: 70.72
# Epoch: [3/10], Step: [625/625], Validation Acc: 69.18
# Epoch: [4/10], Step: [625/625], Validation Acc: 74.56
# Epoch: [5/10], Step: [625/625], Validation Acc: 74.66
# Epoch: [6/10], Step: [625/625], Validation Acc: 74.46
# Epoch: [7/10], Step: [625/625], Validation Acc: 77.58
# Epoch: [8/10], Step: [625/625], Validation Acc: 77.36
# Epoch: [9/10], Step: [625/625], Validation Acc: 77.92
# Epoch: [10/10], Step: [625/625], Validation Acc: 77.66
# 78.736
#
# Now it is 21 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 55.66
# Epoch: [2/10], Step: [625/625], Validation Acc: 77.08
# Epoch: [3/10], Step: [625/625], Validation Acc: 78.5
# Epoch: [4/10], Step: [625/625], Validation Acc: 79.18
# Epoch: [5/10], Step: [625/625], Validation Acc: 79.52
# Epoch: [6/10], Step: [625/625], Validation Acc: 79.28
# Epoch: [7/10], Step: [625/625], Validation Acc: 79.4
# Epoch: [8/10], Step: [625/625], Validation Acc: 79.3
# Epoch: [9/10], Step: [625/625], Validation Acc: 79.3
# Epoch: [10/10], Step: [625/625], Validation Acc: 79.02
# 79.532
#
# Now it is 22 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 50.12
# Epoch: [2/10], Step: [625/625], Validation Acc: 75.06
# Epoch: [3/10], Step: [625/625], Validation Acc: 77.36
# Epoch: [4/10], Step: [625/625], Validation Acc: 77.8
# Epoch: [5/10], Step: [625/625], Validation Acc: 79.08
# Epoch: [6/10], Step: [625/625], Validation Acc: 78.76
# Epoch: [7/10], Step: [625/625], Validation Acc: 78.3
# Epoch: [8/10], Step: [625/625], Validation Acc: 78.62
# Epoch: [9/10], Step: [625/625], Validation Acc: 79.54
# Epoch: [10/10], Step: [625/625], Validation Acc: 79.46
# 79.936
#
# Now it is 23 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 76.44
# Epoch: [2/10], Step: [625/625], Validation Acc: 76.48
# Epoch: [3/10], Step: [625/625], Validation Acc: 77.74
# Epoch: [4/10], Step: [625/625], Validation Acc: 77.56
# Epoch: [5/10], Step: [625/625], Validation Acc: 76.5
# Epoch: [6/10], Step: [625/625], Validation Acc: 75.28
# Epoch: [7/10], Step: [625/625], Validation Acc: 76.84
# Epoch: [8/10], Step: [625/625], Validation Acc: 75.78
# Epoch: [9/10], Step: [625/625], Validation Acc: 75.66
# Epoch: [10/10], Step: [625/625], Validation Acc: 76.34
# 77.168
#
# Now it is 24 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 76.4
# Epoch: [2/10], Step: [625/625], Validation Acc: 77.7
# Epoch: [3/10], Step: [625/625], Validation Acc: 78.66
# Epoch: [4/10], Step: [625/625], Validation Acc: 77.94
# Epoch: [5/10], Step: [625/625], Validation Acc: 77.72
# Epoch: [6/10], Step: [625/625], Validation Acc: 77.6
# Epoch: [7/10], Step: [625/625], Validation Acc: 76.72
# Epoch: [8/10], Step: [625/625], Validation Acc: 76.48
# Epoch: [9/10], Step: [625/625], Validation Acc: 76.48
# Epoch: [10/10], Step: [625/625], Validation Acc: 75.8
# 77.068
#
# Now it is 25 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 49.8
# Epoch: [2/10], Step: [625/625], Validation Acc: 67.24
# Epoch: [3/10], Step: [625/625], Validation Acc: 74.94
# Epoch: [4/10], Step: [625/625], Validation Acc: 71.6
# Epoch: [5/10], Step: [625/625], Validation Acc: 78.0
# Epoch: [6/10], Step: [625/625], Validation Acc: 78.84
# Epoch: [7/10], Step: [625/625], Validation Acc: 79.36
# Epoch: [8/10], Step: [625/625], Validation Acc: 79.44
# Epoch: [9/10], Step: [625/625], Validation Acc: 79.36
# Epoch: [10/10], Step: [625/625], Validation Acc: 79.46
# 80.036
#
# Now it is 26 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 51.94
# Epoch: [2/10], Step: [625/625], Validation Acc: 56.06
# Epoch: [3/10], Step: [625/625], Validation Acc: 72.24
# Epoch: [4/10], Step: [625/625], Validation Acc: 74.84
# Epoch: [5/10], Step: [625/625], Validation Acc: 77.04
# Epoch: [6/10], Step: [625/625], Validation Acc: 78.46
# Epoch: [7/10], Step: [625/625], Validation Acc: 78.9
# Epoch: [8/10], Step: [625/625], Validation Acc: 78.58
# Epoch: [9/10], Step: [625/625], Validation Acc: 78.62
# Epoch: [10/10], Step: [625/625], Validation Acc: 76.96
# 77.328
#
# Now it is 27 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 65.32
# Epoch: [2/10], Step: [625/625], Validation Acc: 74.5
# Epoch: [3/10], Step: [625/625], Validation Acc: 76.1
# Epoch: [4/10], Step: [625/625], Validation Acc: 78.94
# Epoch: [5/10], Step: [625/625], Validation Acc: 79.18
# Epoch: [6/10], Step: [625/625], Validation Acc: 78.0
# Epoch: [7/10], Step: [625/625], Validation Acc: 78.88
# Epoch: [8/10], Step: [625/625], Validation Acc: 78.92
# Epoch: [9/10], Step: [625/625], Validation Acc: 78.38
# Epoch: [10/10], Step: [625/625], Validation Acc: 78.06
# 78.676
#
# Now it is 28 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 67.24
# Epoch: [2/10], Step: [625/625], Validation Acc: 68.88
# Epoch: [3/10], Step: [625/625], Validation Acc: 77.16
# Epoch: [4/10], Step: [625/625], Validation Acc: 79.1
# Epoch: [5/10], Step: [625/625], Validation Acc: 78.98
# Epoch: [6/10], Step: [625/625], Validation Acc: 75.94
# Epoch: [7/10], Step: [625/625], Validation Acc: 80.02
# Epoch: [8/10], Step: [625/625], Validation Acc: 79.1
# Epoch: [9/10], Step: [625/625], Validation Acc: 79.18
# Epoch: [10/10], Step: [625/625], Validation Acc: 79.44
# 79.796
#
# Now it is 29 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 74.0
# Epoch: [2/10], Step: [625/625], Validation Acc: 75.52
# Epoch: [3/10], Step: [625/625], Validation Acc: 68.42
# Epoch: [4/10], Step: [625/625], Validation Acc: 77.22
# Epoch: [5/10], Step: [625/625], Validation Acc: 77.4
# Epoch: [6/10], Step: [625/625], Validation Acc: 76.18
# Epoch: [7/10], Step: [625/625], Validation Acc: 76.24
# Epoch: [8/10], Step: [625/625], Validation Acc: 76.36
# Epoch: [9/10], Step: [625/625], Validation Acc: 76.44
# Epoch: [10/10], Step: [625/625], Validation Acc: 75.54
# 76.224
#
# Now it is 30 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 72.0
# Epoch: [2/10], Step: [625/625], Validation Acc: 79.18
# Epoch: [3/10], Step: [625/625], Validation Acc: 78.3
# Epoch: [4/10], Step: [625/625], Validation Acc: 75.28
# Epoch: [5/10], Step: [625/625], Validation Acc: 77.52
# Epoch: [6/10], Step: [625/625], Validation Acc: 76.1
# Epoch: [7/10], Step: [625/625], Validation Acc: 77.22
# Epoch: [8/10], Step: [625/625], Validation Acc: 76.82
# Epoch: [9/10], Step: [625/625], Validation Acc: 75.66
# Epoch: [10/10], Step: [625/625], Validation Acc: 76.48
# 76.92

# %% [markdown]
# # ngram = 2, max_vocab_size = 20000

# %%
grid = {'emb_dim':[100,200,300,400,500],'optimizer':['Adam','RMSprop'], 'learning_rate': [0.0005,0.001,0.005]}
num_comb = len(ParameterGrid(grid))
count = 0

for j in range(len(ParameterGrid(grid))):
    count += 1
    print("Now it is {} out of {} combinations".format(count, num_comb))
    optimizer,learning_rate, emb_dim = ParameterGrid(grid)[j].values()
    myCsvRow = "optimizer = {}, learning_rate = {}, emb_dim = {}".format(optimizer, learning_rate, emb_dim)
    print(myCsvRow)
    tuning(emb_dim, optimizer, learning_rate)
    print()
# Out:
# Now it is 1 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 51.8
# Epoch: [2/10], Step: [625/625], Validation Acc: 69.76
# Epoch: [3/10], Step: [625/625], Validation Acc: 77.84
# Epoch: [4/10], Step: [625/625], Validation Acc: 80.24
# Epoch: [5/10], Step: [625/625], Validation Acc: 81.3
# Epoch: [6/10], Step: [625/625], Validation Acc: 82.32
# Epoch: [7/10], Step: [625/625], Validation Acc: 82.92
# Epoch: [8/10], Step: [625/625], Validation Acc: 83.22
# Epoch: [9/10], Step: [625/625], Validation Acc: 83.76
# Epoch: [10/10], Step: [625/625], Validation Acc: 84.24
# 84.156
#
# Now it is 2 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 54.92
# Epoch: [2/10], Step: [625/625], Validation Acc: 69.04
# Epoch: [3/10], Step: [625/625], Validation Acc: 77.92
# Epoch: [4/10], Step: [625/625], Validation Acc: 79.08
# Epoch: [5/10], Step: [625/625], Validation Acc: 80.38
# Epoch: [6/10], Step: [625/625], Validation Acc: 82.0
# Epoch: [7/10], Step: [625/625], Validation Acc: 82.76
# Epoch: [8/10], Step: [625/625], Validation Acc: 83.12
# Epoch: [9/10], Step: [625/625], Validation Acc: 82.7
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.88
# 84.132
#
# Now it is 3 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 70.82
# Epoch: [2/10], Step: [625/625], Validation Acc: 79.72
# Epoch: [3/10], Step: [625/625], Validation Acc: 82.1
# Epoch: [4/10], Step: [625/625], Validation Acc: 83.24
# Epoch: [5/10], Step: [625/625], Validation Acc: 83.52
# Epoch: [6/10], Step: [625/625], Validation Acc: 83.86
# Epoch: [7/10], Step: [625/625], Validation Acc: 83.94
# Epoch: [8/10], Step: [625/625], Validation Acc: 84.08
# Epoch: [9/10], Step: [625/625], Validation Acc: 84.18
# Epoch: [10/10], Step: [625/625], Validation Acc: 84.16
# 84.452
#
# Now it is 4 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 73.82
# Epoch: [2/10], Step: [625/625], Validation Acc: 78.24
# Epoch: [3/10], Step: [625/625], Validation Acc: 81.72
# Epoch: [4/10], Step: [625/625], Validation Acc: 82.66
# Epoch: [5/10], Step: [625/625], Validation Acc: 83.26
# Epoch: [6/10], Step: [625/625], Validation Acc: 83.6
# Epoch: [7/10], Step: [625/625], Validation Acc: 83.8
# Epoch: [8/10], Step: [625/625], Validation Acc: 83.9
# Epoch: [9/10], Step: [625/625], Validation Acc: 84.28
# Epoch: [10/10], Step: [625/625], Validation Acc: 84.26
# 84.352
#
# Now it is 5 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 83.02
# Epoch: [2/10], Step: [625/625], Validation Acc: 84.48
# Epoch: [3/10], Step: [625/625], Validation Acc: 83.5
# Epoch: [4/10], Step: [625/625], Validation Acc: 82.52
# Epoch: [5/10], Step: [625/625], Validation Acc: 82.36
# Epoch: [6/10], Step: [625/625], Validation Acc: 82.02
# Epoch: [7/10], Step: [625/625], Validation Acc: 81.74
# Epoch: [8/10], Step: [625/625], Validation Acc: 81.74
# Epoch: [9/10], Step: [625/625], Validation Acc: 81.66
# Epoch: [10/10], Step: [625/625], Validation Acc: 81.4
# 82.276
#
# Now it is 6 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 82.16
# Epoch: [2/10], Step: [625/625], Validation Acc: 84.62
# Epoch: [3/10], Step: [625/625], Validation Acc: 83.32
# Epoch: [4/10], Step: [625/625], Validation Acc: 83.46
# Epoch: [5/10], Step: [625/625], Validation Acc: 83.06
# Epoch: [6/10], Step: [625/625], Validation Acc: 82.24
# Epoch: [7/10], Step: [625/625], Validation Acc: 81.1
# Epoch: [8/10], Step: [625/625], Validation Acc: 81.36
# Epoch: [9/10], Step: [625/625], Validation Acc: 80.96
# Epoch: [10/10], Step: [625/625], Validation Acc: 80.78
# 81.66
#
# Now it is 7 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 63.98
# Epoch: [2/10], Step: [625/625], Validation Acc: 77.1
# Epoch: [3/10], Step: [625/625], Validation Acc: 78.9
# Epoch: [4/10], Step: [625/625], Validation Acc: 81.56
# Epoch: [5/10], Step: [625/625], Validation Acc: 82.32
# Epoch: [6/10], Step: [625/625], Validation Acc: 83.0
# Epoch: [7/10], Step: [625/625], Validation Acc: 83.58
# Epoch: [8/10], Step: [625/625], Validation Acc: 84.28
# Epoch: [9/10], Step: [625/625], Validation Acc: 84.3
# Epoch: [10/10], Step: [625/625], Validation Acc: 84.54
# 84.764
#
# Now it is 8 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 66.42
# Epoch: [2/10], Step: [625/625], Validation Acc: 78.08
# Epoch: [3/10], Step: [625/625], Validation Acc: 78.1
# Epoch: [4/10], Step: [625/625], Validation Acc: 81.6
# Epoch: [5/10], Step: [625/625], Validation Acc: 82.5
# Epoch: [6/10], Step: [625/625], Validation Acc: 83.2
# Epoch: [7/10], Step: [625/625], Validation Acc: 83.8
# Epoch: [8/10], Step: [625/625], Validation Acc: 84.1
# Epoch: [9/10], Step: [625/625], Validation Acc: 83.7
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.64
# 84.64
#
# Now it is 9 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 73.16
# Epoch: [2/10], Step: [625/625], Validation Acc: 81.58
# Epoch: [3/10], Step: [625/625], Validation Acc: 83.62
# Epoch: [4/10], Step: [625/625], Validation Acc: 83.2
# Epoch: [5/10], Step: [625/625], Validation Acc: 84.64
# Epoch: [6/10], Step: [625/625], Validation Acc: 84.06
# Epoch: [7/10], Step: [625/625], Validation Acc: 83.98
# Epoch: [8/10], Step: [625/625], Validation Acc: 83.88
# Epoch: [9/10], Step: [625/625], Validation Acc: 83.78
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.44
# 83.616
#
# Now it is 10 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 77.18
# Epoch: [2/10], Step: [625/625], Validation Acc: 81.24
# Epoch: [3/10], Step: [625/625], Validation Acc: 81.4
# Epoch: [4/10], Step: [625/625], Validation Acc: 82.36
# Epoch: [5/10], Step: [625/625], Validation Acc: 84.0
# Epoch: [6/10], Step: [625/625], Validation Acc: 84.12
# Epoch: [7/10], Step: [625/625], Validation Acc: 84.16
# Epoch: [8/10], Step: [625/625], Validation Acc: 84.18
# Epoch: [9/10], Step: [625/625], Validation Acc: 83.98
# Epoch: [10/10], Step: [625/625], Validation Acc: 84.12
# 84.704
#
# Now it is 11 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 83.6
# Epoch: [2/10], Step: [625/625], Validation Acc: 83.38
# Epoch: [3/10], Step: [625/625], Validation Acc: 82.4
# Epoch: [4/10], Step: [625/625], Validation Acc: 82.28
# Epoch: [5/10], Step: [625/625], Validation Acc: 81.54
# Epoch: [6/10], Step: [625/625], Validation Acc: 81.56
# Epoch: [7/10], Step: [625/625], Validation Acc: 81.36
# Epoch: [8/10], Step: [625/625], Validation Acc: 81.2
# Epoch: [9/10], Step: [625/625], Validation Acc: 81.14
# Epoch: [10/10], Step: [625/625], Validation Acc: 81.04
# 82.02
#
# Now it is 12 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 83.76
# Epoch: [2/10], Step: [625/625], Validation Acc: 84.02
# Epoch: [3/10], Step: [625/625], Validation Acc: 83.26
# Epoch: [4/10], Step: [625/625], Validation Acc: 82.24
# Epoch: [5/10], Step: [625/625], Validation Acc: 82.06
# Epoch: [6/10], Step: [625/625], Validation Acc: 80.98
# Epoch: [7/10], Step: [625/625], Validation Acc: 81.32
# Epoch: [8/10], Step: [625/625], Validation Acc: 79.56
# Epoch: [9/10], Step: [625/625], Validation Acc: 80.28
# Epoch: [10/10], Step: [625/625], Validation Acc: 80.3
# 81.488
#
# Now it is 13 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 70.8
# Epoch: [2/10], Step: [625/625], Validation Acc: 77.28
# Epoch: [3/10], Step: [625/625], Validation Acc: 81.52
# Epoch: [4/10], Step: [625/625], Validation Acc: 83.0
# Epoch: [5/10], Step: [625/625], Validation Acc: 83.5
# Epoch: [6/10], Step: [625/625], Validation Acc: 83.92
# Epoch: [7/10], Step: [625/625], Validation Acc: 84.32
# Epoch: [8/10], Step: [625/625], Validation Acc: 84.32
# Epoch: [9/10], Step: [625/625], Validation Acc: 84.52
# Epoch: [10/10], Step: [625/625], Validation Acc: 84.62
# 84.656
#
# Now it is 14 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 73.52
# Epoch: [2/10], Step: [625/625], Validation Acc: 77.76
# Epoch: [3/10], Step: [625/625], Validation Acc: 80.6
# Epoch: [4/10], Step: [625/625], Validation Acc: 81.42
# Epoch: [5/10], Step: [625/625], Validation Acc: 82.94
# Epoch: [6/10], Step: [625/625], Validation Acc: 83.42
# Epoch: [7/10], Step: [625/625], Validation Acc: 83.54
# Epoch: [8/10], Step: [625/625], Validation Acc: 83.88
# Epoch: [9/10], Step: [625/625], Validation Acc: 83.8
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.92
# 84.74
#
# Now it is 15 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 73.14
# Epoch: [2/10], Step: [625/625], Validation Acc: 82.76
# Epoch: [3/10], Step: [625/625], Validation Acc: 83.54
# Epoch: [4/10], Step: [625/625], Validation Acc: 84.28
# Epoch: [5/10], Step: [625/625], Validation Acc: 84.66
# Epoch: [6/10], Step: [625/625], Validation Acc: 84.48
# Epoch: [7/10], Step: [625/625], Validation Acc: 83.8
# Epoch: [8/10], Step: [625/625], Validation Acc: 84.0
# Epoch: [9/10], Step: [625/625], Validation Acc: 83.7
# Epoch: [10/10], Step: [625/625], Validation Acc: 82.98
# 83.58
#
# Now it is 16 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 79.8
# Epoch: [2/10], Step: [625/625], Validation Acc: 80.9
# Epoch: [3/10], Step: [625/625], Validation Acc: 83.76
# Epoch: [4/10], Step: [625/625], Validation Acc: 84.38
# Epoch: [5/10], Step: [625/625], Validation Acc: 84.76
# Epoch: [6/10], Step: [625/625], Validation Acc: 84.5
# Epoch: [7/10], Step: [625/625], Validation Acc: 84.82
# Epoch: [8/10], Step: [625/625], Validation Acc: 84.72
# Epoch: [9/10], Step: [625/625], Validation Acc: 84.4
# Epoch: [10/10], Step: [625/625], Validation Acc: 84.24
# 84.372
#
# Now it is 17 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 84.12
# Epoch: [2/10], Step: [625/625], Validation Acc: 83.1
# Epoch: [3/10], Step: [625/625], Validation Acc: 82.72
# Epoch: [4/10], Step: [625/625], Validation Acc: 81.62
# Epoch: [5/10], Step: [625/625], Validation Acc: 81.16
# Epoch: [6/10], Step: [625/625], Validation Acc: 81.34
# Epoch: [7/10], Step: [625/625], Validation Acc: 81.14
# Epoch: [8/10], Step: [625/625], Validation Acc: 81.08
# Epoch: [9/10], Step: [625/625], Validation Acc: 81.16
# Epoch: [10/10], Step: [625/625], Validation Acc: 81.16
# 82.244
#
# Now it is 18 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 83.72
# Epoch: [2/10], Step: [625/625], Validation Acc: 83.88
# Epoch: [3/10], Step: [625/625], Validation Acc: 83.02
# Epoch: [4/10], Step: [625/625], Validation Acc: 82.56
# Epoch: [5/10], Step: [625/625], Validation Acc: 81.8
# Epoch: [6/10], Step: [625/625], Validation Acc: 81.5
# Epoch: [7/10], Step: [625/625], Validation Acc: 80.96
# Epoch: [8/10], Step: [625/625], Validation Acc: 80.72
# Epoch: [9/10], Step: [625/625], Validation Acc: 80.7
# Epoch: [10/10], Step: [625/625], Validation Acc: 77.74
# 77.564
#
# Now it is 19 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 75.54
# Epoch: [2/10], Step: [625/625], Validation Acc: 79.26
# Epoch: [3/10], Step: [625/625], Validation Acc: 82.04
# Epoch: [4/10], Step: [625/625], Validation Acc: 83.02
# Epoch: [5/10], Step: [625/625], Validation Acc: 83.56
# Epoch: [6/10], Step: [625/625], Validation Acc: 84.26
# Epoch: [7/10], Step: [625/625], Validation Acc: 84.28
# Epoch: [8/10], Step: [625/625], Validation Acc: 84.22
# Epoch: [9/10], Step: [625/625], Validation Acc: 83.7
# Epoch: [10/10], Step: [625/625], Validation Acc: 84.22
# 84.54
#
# Now it is 20 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 64.12
# Epoch: [2/10], Step: [625/625], Validation Acc: 78.2
# Epoch: [3/10], Step: [625/625], Validation Acc: 81.76
# Epoch: [4/10], Step: [625/625], Validation Acc: 83.06
# Epoch: [5/10], Step: [625/625], Validation Acc: 82.78
# Epoch: [6/10], Step: [625/625], Validation Acc: 84.3
# Epoch: [7/10], Step: [625/625], Validation Acc: 82.86
# Epoch: [8/10], Step: [625/625], Validation Acc: 84.68
# Epoch: [9/10], Step: [625/625], Validation Acc: 84.82
# Epoch: [10/10], Step: [625/625], Validation Acc: 84.76
# 84.62
#
# Now it is 21 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 79.32
# Epoch: [2/10], Step: [625/625], Validation Acc: 82.0
# Epoch: [3/10], Step: [625/625], Validation Acc: 84.16
# Epoch: [4/10], Step: [625/625], Validation Acc: 84.32
# Epoch: [5/10], Step: [625/625], Validation Acc: 84.02
# Epoch: [6/10], Step: [625/625], Validation Acc: 83.96
# Epoch: [7/10], Step: [625/625], Validation Acc: 82.88
# Epoch: [8/10], Step: [625/625], Validation Acc: 83.34
# Epoch: [9/10], Step: [625/625], Validation Acc: 82.88
# Epoch: [10/10], Step: [625/625], Validation Acc: 82.8
# 83.34
#
# Now it is 22 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 79.94
# Epoch: [2/10], Step: [625/625], Validation Acc: 82.66
# Epoch: [3/10], Step: [625/625], Validation Acc: 82.44
# Epoch: [4/10], Step: [625/625], Validation Acc: 84.32
# Epoch: [5/10], Step: [625/625], Validation Acc: 84.62
# Epoch: [6/10], Step: [625/625], Validation Acc: 84.54
# Epoch: [7/10], Step: [625/625], Validation Acc: 84.52
# Epoch: [8/10], Step: [625/625], Validation Acc: 84.18
# Epoch: [9/10], Step: [625/625], Validation Acc: 83.42
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.58
# 83.904
#
# Now it is 23 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 84.38
# Epoch: [2/10], Step: [625/625], Validation Acc: 82.64
# Epoch: [3/10], Step: [625/625], Validation Acc: 82.64
# Epoch: [4/10], Step: [625/625], Validation Acc: 81.42
# Epoch: [5/10], Step: [625/625], Validation Acc: 81.46
# Epoch: [6/10], Step: [625/625], Validation Acc: 81.22
# Epoch: [7/10], Step: [625/625], Validation Acc: 81.4
# Epoch: [8/10], Step: [625/625], Validation Acc: 81.34
# Epoch: [9/10], Step: [625/625], Validation Acc: 81.28
# Epoch: [10/10], Step: [625/625], Validation Acc: 81.12
# 82.192
#
# Now it is 24 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 83.54
# Epoch: [2/10], Step: [625/625], Validation Acc: 84.0
# Epoch: [3/10], Step: [625/625], Validation Acc: 79.28
# Epoch: [4/10], Step: [625/625], Validation Acc: 81.66
# Epoch: [5/10], Step: [625/625], Validation Acc: 81.06
# Epoch: [6/10], Step: [625/625], Validation Acc: 80.72
# Epoch: [7/10], Step: [625/625], Validation Acc: 80.76
# Epoch: [8/10], Step: [625/625], Validation Acc: 80.46
# Epoch: [9/10], Step: [625/625], Validation Acc: 80.42
# Epoch: [10/10], Step: [625/625], Validation Acc: 79.84
# 81.352
#
# Now it is 25 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 69.34
# Epoch: [2/10], Step: [625/625], Validation Acc: 77.58
# Epoch: [3/10], Step: [625/625], Validation Acc: 82.06
# Epoch: [4/10], Step: [625/625], Validation Acc: 83.26
# Epoch: [5/10], Step: [625/625], Validation Acc: 83.72
# Epoch: [6/10], Step: [625/625], Validation Acc: 84.02
# Epoch: [7/10], Step: [625/625], Validation Acc: 84.48
# Epoch: [8/10], Step: [625/625], Validation Acc: 84.3
# Epoch: [9/10], Step: [625/625], Validation Acc: 84.3
# Epoch: [10/10], Step: [625/625], Validation Acc: 84.08
# 84.664
#
# Now it is 26 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 76.12
# Epoch: [2/10], Step: [625/625], Validation Acc: 80.04
# Epoch: [3/10], Step: [625/625], Validation Acc: 81.8
# Epoch: [4/10], Step: [625/625], Validation Acc: 82.94
# Epoch: [5/10], Step: [625/625], Validation Acc: 83.36
# Epoch: [6/10], Step: [625/625], Validation Acc: 82.96
# Epoch: [7/10], Step: [625/625], Validation Acc: 84.3
# Epoch: [8/10], Step: [625/625], Validation Acc: 84.12
# Epoch: [9/10], Step: [625/625], Validation Acc: 84.68
# Epoch: [10/10], Step: [625/625], Validation Acc: 84.24
# 84.644
#
# Now it is 27 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 79.8
# Epoch: [2/10], Step: [625/625], Validation Acc: 82.98
# Epoch: [3/10], Step: [625/625], Validation Acc: 83.88
# Epoch: [4/10], Step: [625/625], Validation Acc: 84.18
# Epoch: [5/10], Step: [625/625], Validation Acc: 84.04
# Epoch: [6/10], Step: [625/625], Validation Acc: 83.82
# Epoch: [7/10], Step: [625/625], Validation Acc: 83.06
# Epoch: [8/10], Step: [625/625], Validation Acc: 82.8
# Epoch: [9/10], Step: [625/625], Validation Acc: 82.94
# Epoch: [10/10], Step: [625/625], Validation Acc: 82.68
# 83.42
#
# Now it is 28 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 80.32
# Epoch: [2/10], Step: [625/625], Validation Acc: 83.02
# Epoch: [3/10], Step: [625/625], Validation Acc: 84.06
# Epoch: [4/10], Step: [625/625], Validation Acc: 84.56
# Epoch: [5/10], Step: [625/625], Validation Acc: 84.7
# Epoch: [6/10], Step: [625/625], Validation Acc: 82.46
# Epoch: [7/10], Step: [625/625], Validation Acc: 83.88
# Epoch: [8/10], Step: [625/625], Validation Acc: 83.98
# Epoch: [9/10], Step: [625/625], Validation Acc: 83.58
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.0
# 83.476
#
# Now it is 29 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 83.42
# Epoch: [2/10], Step: [625/625], Validation Acc: 81.54
# Epoch: [3/10], Step: [625/625], Validation Acc: 81.92
# Epoch: [4/10], Step: [625/625], Validation Acc: 81.2
# Epoch: [5/10], Step: [625/625], Validation Acc: 81.14
# Epoch: [6/10], Step: [625/625], Validation Acc: 80.7
# Epoch: [7/10], Step: [625/625], Validation Acc: 81.08
# Epoch: [8/10], Step: [625/625], Validation Acc: 81.08
# Epoch: [9/10], Step: [625/625], Validation Acc: 81.04
# Epoch: [10/10], Step: [625/625], Validation Acc: 80.9
# 82.044
#
# Now it is 30 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 83.08
# Epoch: [2/10], Step: [625/625], Validation Acc: 83.82
# Epoch: [3/10], Step: [625/625], Validation Acc: 83.0
# Epoch: [4/10], Step: [625/625], Validation Acc: 81.86
# Epoch: [5/10], Step: [625/625], Validation Acc: 82.18
# Epoch: [6/10], Step: [625/625], Validation Acc: 80.72
# Epoch: [7/10], Step: [625/625], Validation Acc: 80.8
# Epoch: [8/10], Step: [625/625], Validation Acc: 80.76
# Epoch: [9/10], Step: [625/625], Validation Acc: 80.62
# Epoch: [10/10], Step: [625/625], Validation Acc: 80.3
# 81.268

# %% [markdown]
# # ngram = 1, max_vocab_size = 20000

# %%
grid = {'emb_dim':[100,200,300,400,500],'optimizer':['Adam','RMSprop'], 'learning_rate': [0.0005,0.001,0.005]}
num_comb = len(ParameterGrid(grid))
count = 0

for j in range(len(ParameterGrid(grid))):
    count += 1
    print("Now it is {} out of {} combinations".format(count, num_comb))
    optimizer,learning_rate, emb_dim = ParameterGrid(grid)[j].values()
    myCsvRow = "optimizer = {}, learning_rate = {}, emb_dim = {}".format(optimizer, learning_rate, emb_dim)
    print(myCsvRow)
    tuning(emb_dim, optimizer, learning_rate)
    print()
# Out:
# Now it is 1 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 64.98
# Epoch: [2/10], Step: [625/625], Validation Acc: 74.06
# Epoch: [3/10], Step: [625/625], Validation Acc: 79.68
# Epoch: [4/10], Step: [625/625], Validation Acc: 82.0
# Epoch: [5/10], Step: [625/625], Validation Acc: 83.1
# Epoch: [6/10], Step: [625/625], Validation Acc: 84.34
# Epoch: [7/10], Step: [625/625], Validation Acc: 84.92
# Epoch: [8/10], Step: [625/625], Validation Acc: 85.44
# Epoch: [9/10], Step: [625/625], Validation Acc: 85.76
# Epoch: [10/10], Step: [625/625], Validation Acc: 86.16
# 85.588
#
# Now it is 2 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 69.6
# Epoch: [2/10], Step: [625/625], Validation Acc: 76.3
# Epoch: [3/10], Step: [625/625], Validation Acc: 79.58
# Epoch: [4/10], Step: [625/625], Validation Acc: 81.98
# Epoch: [5/10], Step: [625/625], Validation Acc: 83.28
# Epoch: [6/10], Step: [625/625], Validation Acc: 84.2
# Epoch: [7/10], Step: [625/625], Validation Acc: 84.76
# Epoch: [8/10], Step: [625/625], Validation Acc: 85.22
# Epoch: [9/10], Step: [625/625], Validation Acc: 85.64
# Epoch: [10/10], Step: [625/625], Validation Acc: 86.0
# 85.696
#
# Now it is 3 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 73.82
# Epoch: [2/10], Step: [625/625], Validation Acc: 82.26
# Epoch: [3/10], Step: [625/625], Validation Acc: 84.64
# Epoch: [4/10], Step: [625/625], Validation Acc: 85.28
# Epoch: [5/10], Step: [625/625], Validation Acc: 86.1
# Epoch: [6/10], Step: [625/625], Validation Acc: 86.52
# Epoch: [7/10], Step: [625/625], Validation Acc: 87.08
# Epoch: [8/10], Step: [625/625], Validation Acc: 87.14
# Epoch: [9/10], Step: [625/625], Validation Acc: 87.44
# Epoch: [10/10], Step: [625/625], Validation Acc: 87.14
# 85.564
#
# Now it is 4 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 76.26
# Epoch: [2/10], Step: [625/625], Validation Acc: 81.78
# Epoch: [3/10], Step: [625/625], Validation Acc: 83.72
# Epoch: [4/10], Step: [625/625], Validation Acc: 84.66
# Epoch: [5/10], Step: [625/625], Validation Acc: 85.88
# Epoch: [6/10], Step: [625/625], Validation Acc: 86.84
# Epoch: [7/10], Step: [625/625], Validation Acc: 87.12
# Epoch: [8/10], Step: [625/625], Validation Acc: 86.94
# Epoch: [9/10], Step: [625/625], Validation Acc: 87.18
# Epoch: [10/10], Step: [625/625], Validation Acc: 87.4
# 85.448
#
# Now it is 5 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 85.88
# Epoch: [2/10], Step: [625/625], Validation Acc: 87.12
# Epoch: [3/10], Step: [625/625], Validation Acc: 86.4
# Epoch: [4/10], Step: [625/625], Validation Acc: 85.96
# Epoch: [5/10], Step: [625/625], Validation Acc: 85.54
# Epoch: [6/10], Step: [625/625], Validation Acc: 85.22
# Epoch: [7/10], Step: [625/625], Validation Acc: 84.94
# Epoch: [8/10], Step: [625/625], Validation Acc: 84.9
# Epoch: [9/10], Step: [625/625], Validation Acc: 84.46
# Epoch: [10/10], Step: [625/625], Validation Acc: 84.64
# 81.408
#
# Now it is 6 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 85.96
# Epoch: [2/10], Step: [625/625], Validation Acc: 87.08
# Epoch: [3/10], Step: [625/625], Validation Acc: 87.2
# Epoch: [4/10], Step: [625/625], Validation Acc: 86.66
# Epoch: [5/10], Step: [625/625], Validation Acc: 86.26
# Epoch: [6/10], Step: [625/625], Validation Acc: 85.76
# Epoch: [7/10], Step: [625/625], Validation Acc: 84.84
# Epoch: [8/10], Step: [625/625], Validation Acc: 84.96
# Epoch: [9/10], Step: [625/625], Validation Acc: 84.5
# Epoch: [10/10], Step: [625/625], Validation Acc: 84.7
# 80.888
#
# Now it is 7 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 70.94
# Epoch: [2/10], Step: [625/625], Validation Acc: 78.78
# Epoch: [3/10], Step: [625/625], Validation Acc: 82.2
# Epoch: [4/10], Step: [625/625], Validation Acc: 84.1
# Epoch: [5/10], Step: [625/625], Validation Acc: 84.84
# Epoch: [6/10], Step: [625/625], Validation Acc: 85.62
# Epoch: [7/10], Step: [625/625], Validation Acc: 86.18
# Epoch: [8/10], Step: [625/625], Validation Acc: 86.6
# Epoch: [9/10], Step: [625/625], Validation Acc: 87.02
# Epoch: [10/10], Step: [625/625], Validation Acc: 87.1
# 85.792
#
# Now it is 8 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 70.98
# Epoch: [2/10], Step: [625/625], Validation Acc: 79.06
# Epoch: [3/10], Step: [625/625], Validation Acc: 82.4
# Epoch: [4/10], Step: [625/625], Validation Acc: 84.24
# Epoch: [5/10], Step: [625/625], Validation Acc: 84.86
# Epoch: [6/10], Step: [625/625], Validation Acc: 85.32
# Epoch: [7/10], Step: [625/625], Validation Acc: 86.32
# Epoch: [8/10], Step: [625/625], Validation Acc: 86.64
# Epoch: [9/10], Step: [625/625], Validation Acc: 87.2
# Epoch: [10/10], Step: [625/625], Validation Acc: 87.58
# 85.904
#
# Now it is 9 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 78.76
# Epoch: [2/10], Step: [625/625], Validation Acc: 83.66
# Epoch: [3/10], Step: [625/625], Validation Acc: 85.56
# Epoch: [4/10], Step: [625/625], Validation Acc: 86.86
# Epoch: [5/10], Step: [625/625], Validation Acc: 87.34
# Epoch: [6/10], Step: [625/625], Validation Acc: 87.04
# Epoch: [7/10], Step: [625/625], Validation Acc: 87.06
# Epoch: [8/10], Step: [625/625], Validation Acc: 86.98
# Epoch: [9/10], Step: [625/625], Validation Acc: 86.68
# Epoch: [10/10], Step: [625/625], Validation Acc: 86.66
# 84.576
#
# Now it is 10 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 80.16
# Epoch: [2/10], Step: [625/625], Validation Acc: 83.18
# Epoch: [3/10], Step: [625/625], Validation Acc: 85.44
# Epoch: [4/10], Step: [625/625], Validation Acc: 86.38
# Epoch: [5/10], Step: [625/625], Validation Acc: 87.06
# Epoch: [6/10], Step: [625/625], Validation Acc: 87.28
# Epoch: [7/10], Step: [625/625], Validation Acc: 87.42
# Epoch: [8/10], Step: [625/625], Validation Acc: 87.64
# Epoch: [9/10], Step: [625/625], Validation Acc: 87.42
# Epoch: [10/10], Step: [625/625], Validation Acc: 87.38
# 84.776
#
# Now it is 11 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 87.06
# Epoch: [2/10], Step: [625/625], Validation Acc: 87.16
# Epoch: [3/10], Step: [625/625], Validation Acc: 86.68
# Epoch: [4/10], Step: [625/625], Validation Acc: 85.7
# Epoch: [5/10], Step: [625/625], Validation Acc: 85.52
# Epoch: [6/10], Step: [625/625], Validation Acc: 84.64
# Epoch: [7/10], Step: [625/625], Validation Acc: 84.56
# Epoch: [8/10], Step: [625/625], Validation Acc: 84.48
# Epoch: [9/10], Step: [625/625], Validation Acc: 84.46
# Epoch: [10/10], Step: [625/625], Validation Acc: 84.52
# 81.316
#
# Now it is 12 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 86.16
# Epoch: [2/10], Step: [625/625], Validation Acc: 87.28
# Epoch: [3/10], Step: [625/625], Validation Acc: 86.5
# Epoch: [4/10], Step: [625/625], Validation Acc: 85.7
# Epoch: [5/10], Step: [625/625], Validation Acc: 85.12
# Epoch: [6/10], Step: [625/625], Validation Acc: 84.7
# Epoch: [7/10], Step: [625/625], Validation Acc: 84.18
# Epoch: [8/10], Step: [625/625], Validation Acc: 84.2
# Epoch: [9/10], Step: [625/625], Validation Acc: 84.1
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.74
# 80.108
#
# Now it is 13 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 73.1
# Epoch: [2/10], Step: [625/625], Validation Acc: 81.42
# Epoch: [3/10], Step: [625/625], Validation Acc: 83.54
# Epoch: [4/10], Step: [625/625], Validation Acc: 84.76
# Epoch: [5/10], Step: [625/625], Validation Acc: 85.84
# Epoch: [6/10], Step: [625/625], Validation Acc: 86.02
# Epoch: [7/10], Step: [625/625], Validation Acc: 86.9
# Epoch: [8/10], Step: [625/625], Validation Acc: 87.12
# Epoch: [9/10], Step: [625/625], Validation Acc: 87.34
# Epoch: [10/10], Step: [625/625], Validation Acc: 87.3
# 85.304
#
# Now it is 14 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 75.7
# Epoch: [2/10], Step: [625/625], Validation Acc: 81.06
# Epoch: [3/10], Step: [625/625], Validation Acc: 83.3
# Epoch: [4/10], Step: [625/625], Validation Acc: 84.94
# Epoch: [5/10], Step: [625/625], Validation Acc: 85.18
# Epoch: [6/10], Step: [625/625], Validation Acc: 86.14
# Epoch: [7/10], Step: [625/625], Validation Acc: 86.92
# Epoch: [8/10], Step: [625/625], Validation Acc: 87.36
# Epoch: [9/10], Step: [625/625], Validation Acc: 87.26
# Epoch: [10/10], Step: [625/625], Validation Acc: 87.3
# 85.648
#
# Now it is 15 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 80.22
# Epoch: [2/10], Step: [625/625], Validation Acc: 84.16
# Epoch: [3/10], Step: [625/625], Validation Acc: 86.08
# Epoch: [4/10], Step: [625/625], Validation Acc: 86.9
# Epoch: [5/10], Step: [625/625], Validation Acc: 87.06
# Epoch: [6/10], Step: [625/625], Validation Acc: 87.1
# Epoch: [7/10], Step: [625/625], Validation Acc: 87.12
# Epoch: [8/10], Step: [625/625], Validation Acc: 86.94
# Epoch: [9/10], Step: [625/625], Validation Acc: 86.74
# Epoch: [10/10], Step: [625/625], Validation Acc: 86.3
# 84.028
#
# Now it is 16 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 80.86
# Epoch: [2/10], Step: [625/625], Validation Acc: 84.7
# Epoch: [3/10], Step: [625/625], Validation Acc: 86.32
# Epoch: [4/10], Step: [625/625], Validation Acc: 86.68
# Epoch: [5/10], Step: [625/625], Validation Acc: 86.9
# Epoch: [6/10], Step: [625/625], Validation Acc: 87.54
# Epoch: [7/10], Step: [625/625], Validation Acc: 87.46
# Epoch: [8/10], Step: [625/625], Validation Acc: 87.38
# Epoch: [9/10], Step: [625/625], Validation Acc: 87.22
# Epoch: [10/10], Step: [625/625], Validation Acc: 86.54
# 84.168
#
# Now it is 17 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 85.28
# Epoch: [2/10], Step: [625/625], Validation Acc: 86.96
# Epoch: [3/10], Step: [625/625], Validation Acc: 85.96
# Epoch: [4/10], Step: [625/625], Validation Acc: 85.28
# Epoch: [5/10], Step: [625/625], Validation Acc: 85.14
# Epoch: [6/10], Step: [625/625], Validation Acc: 84.54
# Epoch: [7/10], Step: [625/625], Validation Acc: 84.52
# Epoch: [8/10], Step: [625/625], Validation Acc: 84.72
# Epoch: [9/10], Step: [625/625], Validation Acc: 84.66
# Epoch: [10/10], Step: [625/625], Validation Acc: 84.76
# 81.484
#
# Now it is 18 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 86.68
# Epoch: [2/10], Step: [625/625], Validation Acc: 86.82
# Epoch: [3/10], Step: [625/625], Validation Acc: 85.74
# Epoch: [4/10], Step: [625/625], Validation Acc: 85.98
# Epoch: [5/10], Step: [625/625], Validation Acc: 85.4
# Epoch: [6/10], Step: [625/625], Validation Acc: 85.0
# Epoch: [7/10], Step: [625/625], Validation Acc: 84.34
# Epoch: [8/10], Step: [625/625], Validation Acc: 83.44
# Epoch: [9/10], Step: [625/625], Validation Acc: 84.0
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.16
# 79.5
#
# Now it is 19 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 76.18
# Epoch: [2/10], Step: [625/625], Validation Acc: 81.86
# Epoch: [3/10], Step: [625/625], Validation Acc: 84.1
# Epoch: [4/10], Step: [625/625], Validation Acc: 85.2
# Epoch: [5/10], Step: [625/625], Validation Acc: 85.88
# Epoch: [6/10], Step: [625/625], Validation Acc: 86.34
# Epoch: [7/10], Step: [625/625], Validation Acc: 86.78
# Epoch: [8/10], Step: [625/625], Validation Acc: 86.82
# Epoch: [9/10], Step: [625/625], Validation Acc: 86.86
# Epoch: [10/10], Step: [625/625], Validation Acc: 86.86
# 85.176
#
# Now it is 20 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 76.36
# Epoch: [2/10], Step: [625/625], Validation Acc: 81.26
# Epoch: [3/10], Step: [625/625], Validation Acc: 83.58
# Epoch: [4/10], Step: [625/625], Validation Acc: 84.76
# Epoch: [5/10], Step: [625/625], Validation Acc: 85.56
# Epoch: [6/10], Step: [625/625], Validation Acc: 86.32
# Epoch: [7/10], Step: [625/625], Validation Acc: 86.78
# Epoch: [8/10], Step: [625/625], Validation Acc: 87.1
# Epoch: [9/10], Step: [625/625], Validation Acc: 87.06
# Epoch: [10/10], Step: [625/625], Validation Acc: 87.24
# 85.664
#
# Now it is 21 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 81.56
# Epoch: [2/10], Step: [625/625], Validation Acc: 85.04
# Epoch: [3/10], Step: [625/625], Validation Acc: 86.36
# Epoch: [4/10], Step: [625/625], Validation Acc: 86.34
# Epoch: [5/10], Step: [625/625], Validation Acc: 86.98
# Epoch: [6/10], Step: [625/625], Validation Acc: 87.34
# Epoch: [7/10], Step: [625/625], Validation Acc: 87.12
# Epoch: [8/10], Step: [625/625], Validation Acc: 87.06
# Epoch: [9/10], Step: [625/625], Validation Acc: 86.52
# Epoch: [10/10], Step: [625/625], Validation Acc: 86.18
# 83.392
#
# Now it is 22 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 82.52
# Epoch: [2/10], Step: [625/625], Validation Acc: 84.44
# Epoch: [3/10], Step: [625/625], Validation Acc: 85.98
# Epoch: [4/10], Step: [625/625], Validation Acc: 87.54
# Epoch: [5/10], Step: [625/625], Validation Acc: 87.32
# Epoch: [6/10], Step: [625/625], Validation Acc: 87.6
# Epoch: [7/10], Step: [625/625], Validation Acc: 87.36
# Epoch: [8/10], Step: [625/625], Validation Acc: 87.5
# Epoch: [9/10], Step: [625/625], Validation Acc: 87.08
# Epoch: [10/10], Step: [625/625], Validation Acc: 86.92
# 83.844
#
# Now it is 23 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 86.46
# Epoch: [2/10], Step: [625/625], Validation Acc: 86.58
# Epoch: [3/10], Step: [625/625], Validation Acc: 85.08
# Epoch: [4/10], Step: [625/625], Validation Acc: 83.78
# Epoch: [5/10], Step: [625/625], Validation Acc: 85.08
# Epoch: [6/10], Step: [625/625], Validation Acc: 84.2
# Epoch: [7/10], Step: [625/625], Validation Acc: 84.58
# Epoch: [8/10], Step: [625/625], Validation Acc: 84.86
# Epoch: [9/10], Step: [625/625], Validation Acc: 84.38
# Epoch: [10/10], Step: [625/625], Validation Acc: 84.66
# 81.304
#
# Now it is 24 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 87.02
# Epoch: [2/10], Step: [625/625], Validation Acc: 87.22
# Epoch: [3/10], Step: [625/625], Validation Acc: 85.6
# Epoch: [4/10], Step: [625/625], Validation Acc: 85.48
# Epoch: [5/10], Step: [625/625], Validation Acc: 84.94
# Epoch: [6/10], Step: [625/625], Validation Acc: 84.3
# Epoch: [7/10], Step: [625/625], Validation Acc: 84.68
# Epoch: [8/10], Step: [625/625], Validation Acc: 84.6
# Epoch: [9/10], Step: [625/625], Validation Acc: 84.0
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.64
# 80.508
#
# Now it is 25 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 76.16
# Epoch: [2/10], Step: [625/625], Validation Acc: 82.26
# Epoch: [3/10], Step: [625/625], Validation Acc: 84.34
# Epoch: [4/10], Step: [625/625], Validation Acc: 85.8
# Epoch: [5/10], Step: [625/625], Validation Acc: 85.8
# Epoch: [6/10], Step: [625/625], Validation Acc: 86.7
# Epoch: [7/10], Step: [625/625], Validation Acc: 87.14
# Epoch: [8/10], Step: [625/625], Validation Acc: 87.08
# Epoch: [9/10], Step: [625/625], Validation Acc: 87.12
# Epoch: [10/10], Step: [625/625], Validation Acc: 86.96
# 84.732
#
# Now it is 26 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 76.56
# Epoch: [2/10], Step: [625/625], Validation Acc: 82.54
# Epoch: [3/10], Step: [625/625], Validation Acc: 84.56
# Epoch: [4/10], Step: [625/625], Validation Acc: 85.58
# Epoch: [5/10], Step: [625/625], Validation Acc: 86.12
# Epoch: [6/10], Step: [625/625], Validation Acc: 86.7
# Epoch: [7/10], Step: [625/625], Validation Acc: 86.84
# Epoch: [8/10], Step: [625/625], Validation Acc: 86.96
# Epoch: [9/10], Step: [625/625], Validation Acc: 87.24
# Epoch: [10/10], Step: [625/625], Validation Acc: 87.3
# 85.28
#
# Now it is 27 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 81.32
# Epoch: [2/10], Step: [625/625], Validation Acc: 85.16
# Epoch: [3/10], Step: [625/625], Validation Acc: 86.76
# Epoch: [4/10], Step: [625/625], Validation Acc: 87.12
# Epoch: [5/10], Step: [625/625], Validation Acc: 86.58
# Epoch: [6/10], Step: [625/625], Validation Acc: 87.24
# Epoch: [7/10], Step: [625/625], Validation Acc: 86.92
# Epoch: [8/10], Step: [625/625], Validation Acc: 86.62
# Epoch: [9/10], Step: [625/625], Validation Acc: 86.18
# Epoch: [10/10], Step: [625/625], Validation Acc: 85.98
# 83.06
#
# Now it is 28 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 81.62
# Epoch: [2/10], Step: [625/625], Validation Acc: 84.9
# Epoch: [3/10], Step: [625/625], Validation Acc: 86.72
# Epoch: [4/10], Step: [625/625], Validation Acc: 87.0
# Epoch: [5/10], Step: [625/625], Validation Acc: 87.08
# Epoch: [6/10], Step: [625/625], Validation Acc: 87.04
# Epoch: [7/10], Step: [625/625], Validation Acc: 86.98
# Epoch: [8/10], Step: [625/625], Validation Acc: 86.9
# Epoch: [9/10], Step: [625/625], Validation Acc: 86.6
# Epoch: [10/10], Step: [625/625], Validation Acc: 85.98
# 82.956
#
# Now it is 29 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 86.76
# Epoch: [2/10], Step: [625/625], Validation Acc: 85.7
# Epoch: [3/10], Step: [625/625], Validation Acc: 85.6
# Epoch: [4/10], Step: [625/625], Validation Acc: 84.92
# Epoch: [5/10], Step: [625/625], Validation Acc: 84.5
# Epoch: [6/10], Step: [625/625], Validation Acc: 84.4
# Epoch: [7/10], Step: [625/625], Validation Acc: 84.04
# Epoch: [8/10], Step: [625/625], Validation Acc: 83.68
# Epoch: [9/10], Step: [625/625], Validation Acc: 84.12
# Epoch: [10/10], Step: [625/625], Validation Acc: 84.06
# 80.976
#
# Now it is 30 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 85.66
# Epoch: [2/10], Step: [625/625], Validation Acc: 87.0
# Epoch: [3/10], Step: [625/625], Validation Acc: 85.84
# Epoch: [4/10], Step: [625/625], Validation Acc: 85.6
# Epoch: [5/10], Step: [625/625], Validation Acc: 84.94
# Epoch: [6/10], Step: [625/625], Validation Acc: 84.52
# Epoch: [7/10], Step: [625/625], Validation Acc: 84.44
# Epoch: [8/10], Step: [625/625], Validation Acc: 84.04
# Epoch: [9/10], Step: [625/625], Validation Acc: 83.74
# Epoch: [10/10], Step: [625/625], Validation Acc: 83.82
# 80.096

# %% [markdown]
# # ngram = 4, max_vocab_size = 10000

# %%
grid = {'emb_dim':[100,200,300,400,500],'optimizer':['Adam','RMSprop'], 'learning_rate': [0.0005,0.001,0.005]}
num_comb = len(ParameterGrid(grid))
count = 0

for j in range(len(ParameterGrid(grid))):
    count += 1
    print("Now it is {} out of {} combinations".format(count, num_comb))
    optimizer,learning_rate, emb_dim = ParameterGrid(grid)[j].values()
    myCsvRow = "optimizer = {}, learning_rate = {}, emb_dim = {}".format(optimizer, learning_rate, emb_dim)
    print(myCsvRow)
    tuning(emb_dim, optimizer, learning_rate)
    print()
# Out:
# Now it is 1 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 50.3
# Epoch: [2/10], Step: [625/625], Validation Acc: 50.92
# Epoch: [3/10], Step: [625/625], Validation Acc: 58.9
# Epoch: [4/10], Step: [625/625], Validation Acc: 49.84
# Epoch: [5/10], Step: [625/625], Validation Acc: 51.96
# Epoch: [6/10], Step: [625/625], Validation Acc: 57.2
# Epoch: [7/10], Step: [625/625], Validation Acc: 67.72
# Epoch: [8/10], Step: [625/625], Validation Acc: 70.6
# Epoch: [9/10], Step: [625/625], Validation Acc: 69.8
# Epoch: [10/10], Step: [625/625], Validation Acc: 67.4
# 67.38
#
# Now it is 2 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 49.7
# Epoch: [2/10], Step: [625/625], Validation Acc: 55.7
# Epoch: [3/10], Step: [625/625], Validation Acc: 52.92
# Epoch: [4/10], Step: [625/625], Validation Acc: 56.68
# Epoch: [5/10], Step: [625/625], Validation Acc: 55.94
# Epoch: [6/10], Step: [625/625], Validation Acc: 54.58
# Epoch: [7/10], Step: [625/625], Validation Acc: 67.6
# Epoch: [8/10], Step: [625/625], Validation Acc: 68.12
# Epoch: [9/10], Step: [625/625], Validation Acc: 63.44
# Epoch: [10/10], Step: [625/625], Validation Acc: 70.26
# 70.248
#
# Now it is 3 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 50.42
# Epoch: [2/10], Step: [625/625], Validation Acc: 50.12
# Epoch: [3/10], Step: [625/625], Validation Acc: 51.06
# Epoch: [4/10], Step: [625/625], Validation Acc: 58.16
# Epoch: [5/10], Step: [625/625], Validation Acc: 68.16
# Epoch: [6/10], Step: [625/625], Validation Acc: 66.56
# Epoch: [7/10], Step: [625/625], Validation Acc: 70.74
# Epoch: [8/10], Step: [625/625], Validation Acc: 66.16
# Epoch: [9/10], Step: [625/625], Validation Acc: 70.52
# Epoch: [10/10], Step: [625/625], Validation Acc: 70.94
# 70.952
#
# Now it is 4 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 50.36
# Epoch: [2/10], Step: [625/625], Validation Acc: 53.46
# Epoch: [3/10], Step: [625/625], Validation Acc: 52.48
# Epoch: [4/10], Step: [625/625], Validation Acc: 51.54
# Epoch: [5/10], Step: [625/625], Validation Acc: 70.4
# Epoch: [6/10], Step: [625/625], Validation Acc: 67.96
# Epoch: [7/10], Step: [625/625], Validation Acc: 71.62
# Epoch: [8/10], Step: [625/625], Validation Acc: 65.86
# Epoch: [9/10], Step: [625/625], Validation Acc: 72.4
# Epoch: [10/10], Step: [625/625], Validation Acc: 72.22
# 71.464
#
# Now it is 5 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 55.34
# Epoch: [2/10], Step: [625/625], Validation Acc: 70.92
# Epoch: [3/10], Step: [625/625], Validation Acc: 69.34
# Epoch: [4/10], Step: [625/625], Validation Acc: 71.96
# Epoch: [5/10], Step: [625/625], Validation Acc: 72.92
# Epoch: [6/10], Step: [625/625], Validation Acc: 72.52
# Epoch: [7/10], Step: [625/625], Validation Acc: 71.74
# Epoch: [8/10], Step: [625/625], Validation Acc: 68.4
# Epoch: [9/10], Step: [625/625], Validation Acc: 71.3
# Epoch: [10/10], Step: [625/625], Validation Acc: 70.88
# 70.912
#
# Now it is 6 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 100
# Epoch: [1/10], Step: [625/625], Validation Acc: 62.88
# Epoch: [2/10], Step: [625/625], Validation Acc: 69.0
# Epoch: [3/10], Step: [625/625], Validation Acc: 68.96
# Epoch: [4/10], Step: [625/625], Validation Acc: 69.72
# Epoch: [5/10], Step: [625/625], Validation Acc: 66.88
# Epoch: [6/10], Step: [625/625], Validation Acc: 71.58
# Epoch: [7/10], Step: [625/625], Validation Acc: 71.5
# Epoch: [8/10], Step: [625/625], Validation Acc: 72.14
# Epoch: [9/10], Step: [625/625], Validation Acc: 70.94
# Epoch: [10/10], Step: [625/625], Validation Acc: 70.46
# 69.316
#
# Now it is 7 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 50.56
# Epoch: [2/10], Step: [625/625], Validation Acc: 49.74
# Epoch: [3/10], Step: [625/625], Validation Acc: 52.36
# Epoch: [4/10], Step: [625/625], Validation Acc: 51.3
# Epoch: [5/10], Step: [625/625], Validation Acc: 69.44
# Epoch: [6/10], Step: [625/625], Validation Acc: 52.74
# Epoch: [7/10], Step: [625/625], Validation Acc: 67.66
# Epoch: [8/10], Step: [625/625], Validation Acc: 66.72
# Epoch: [9/10], Step: [625/625], Validation Acc: 69.8
# Epoch: [10/10], Step: [625/625], Validation Acc: 65.9
# 66.644
#
# Now it is 8 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 49.7
# Epoch: [2/10], Step: [625/625], Validation Acc: 50.12
# Epoch: [3/10], Step: [625/625], Validation Acc: 51.24
# Epoch: [4/10], Step: [625/625], Validation Acc: 56.3
# Epoch: [5/10], Step: [625/625], Validation Acc: 55.5
# Epoch: [6/10], Step: [625/625], Validation Acc: 57.82
# Epoch: [7/10], Step: [625/625], Validation Acc: 57.82
# Epoch: [8/10], Step: [625/625], Validation Acc: 64.32
# Epoch: [9/10], Step: [625/625], Validation Acc: 62.88
# Epoch: [10/10], Step: [625/625], Validation Acc: 69.88
# 69.648
#
# Now it is 9 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 52.1
# Epoch: [2/10], Step: [625/625], Validation Acc: 65.52
# Epoch: [3/10], Step: [625/625], Validation Acc: 57.32
# Epoch: [4/10], Step: [625/625], Validation Acc: 59.4
# Epoch: [5/10], Step: [625/625], Validation Acc: 65.34
# Epoch: [6/10], Step: [625/625], Validation Acc: 70.12
# Epoch: [7/10], Step: [625/625], Validation Acc: 69.94
# Epoch: [8/10], Step: [625/625], Validation Acc: 72.22
# Epoch: [9/10], Step: [625/625], Validation Acc: 72.52
# Epoch: [10/10], Step: [625/625], Validation Acc: 69.76
# 69.264
#
# Now it is 10 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 49.7
# Epoch: [2/10], Step: [625/625], Validation Acc: 66.24
# Epoch: [3/10], Step: [625/625], Validation Acc: 57.04
# Epoch: [4/10], Step: [625/625], Validation Acc: 66.96
# Epoch: [5/10], Step: [625/625], Validation Acc: 66.42
# Epoch: [6/10], Step: [625/625], Validation Acc: 67.54
# Epoch: [7/10], Step: [625/625], Validation Acc: 56.52
# Epoch: [8/10], Step: [625/625], Validation Acc: 71.28
# Epoch: [9/10], Step: [625/625], Validation Acc: 72.16
# Epoch: [10/10], Step: [625/625], Validation Acc: 70.74
# 70.248
#
# Now it is 11 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 64.22
# Epoch: [2/10], Step: [625/625], Validation Acc: 72.98
# Epoch: [3/10], Step: [625/625], Validation Acc: 72.78
# Epoch: [4/10], Step: [625/625], Validation Acc: 70.82
# Epoch: [5/10], Step: [625/625], Validation Acc: 70.34
# Epoch: [6/10], Step: [625/625], Validation Acc: 70.14
# Epoch: [7/10], Step: [625/625], Validation Acc: 71.26
# Epoch: [8/10], Step: [625/625], Validation Acc: 69.8
# Epoch: [9/10], Step: [625/625], Validation Acc: 70.42
# Epoch: [10/10], Step: [625/625], Validation Acc: 70.3
# 69.224
#
# Now it is 12 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 200
# Epoch: [1/10], Step: [625/625], Validation Acc: 67.74
# Epoch: [2/10], Step: [625/625], Validation Acc: 70.28
# Epoch: [3/10], Step: [625/625], Validation Acc: 71.52
# Epoch: [4/10], Step: [625/625], Validation Acc: 70.4
# Epoch: [5/10], Step: [625/625], Validation Acc: 63.44
# Epoch: [6/10], Step: [625/625], Validation Acc: 70.14
# Epoch: [7/10], Step: [625/625], Validation Acc: 71.5
# Epoch: [8/10], Step: [625/625], Validation Acc: 71.52
# Epoch: [9/10], Step: [625/625], Validation Acc: 71.24
# Epoch: [10/10], Step: [625/625], Validation Acc: 71.52
# 70.852
#
# Now it is 13 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 49.7
# Epoch: [2/10], Step: [625/625], Validation Acc: 50.72
# Epoch: [3/10], Step: [625/625], Validation Acc: 54.6
# Epoch: [4/10], Step: [625/625], Validation Acc: 60.82
# Epoch: [5/10], Step: [625/625], Validation Acc: 55.78
# Epoch: [6/10], Step: [625/625], Validation Acc: 70.94
# Epoch: [7/10], Step: [625/625], Validation Acc: 70.76
# Epoch: [8/10], Step: [625/625], Validation Acc: 66.74
# Epoch: [9/10], Step: [625/625], Validation Acc: 71.96
# Epoch: [10/10], Step: [625/625], Validation Acc: 71.72
# 71.184
#
# Now it is 14 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 50.78
# Epoch: [2/10], Step: [625/625], Validation Acc: 49.76
# Epoch: [3/10], Step: [625/625], Validation Acc: 60.56
# Epoch: [4/10], Step: [625/625], Validation Acc: 50.8
# Epoch: [5/10], Step: [625/625], Validation Acc: 70.24
# Epoch: [6/10], Step: [625/625], Validation Acc: 62.66
# Epoch: [7/10], Step: [625/625], Validation Acc: 65.4
# Epoch: [8/10], Step: [625/625], Validation Acc: 69.74
# Epoch: [9/10], Step: [625/625], Validation Acc: 70.64
# Epoch: [10/10], Step: [625/625], Validation Acc: 68.32
# 68.66
#
# Now it is 15 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 50.44
# Epoch: [2/10], Step: [625/625], Validation Acc: 68.94
# Epoch: [3/10], Step: [625/625], Validation Acc: 69.92
# Epoch: [4/10], Step: [625/625], Validation Acc: 69.32
# Epoch: [5/10], Step: [625/625], Validation Acc: 70.24
# Epoch: [6/10], Step: [625/625], Validation Acc: 70.18
# Epoch: [7/10], Step: [625/625], Validation Acc: 71.84
# Epoch: [8/10], Step: [625/625], Validation Acc: 71.52
# Epoch: [9/10], Step: [625/625], Validation Acc: 71.7
# Epoch: [10/10], Step: [625/625], Validation Acc: 71.14
# 71.428
#
# Now it is 16 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 49.74
# Epoch: [2/10], Step: [625/625], Validation Acc: 50.34
# Epoch: [3/10], Step: [625/625], Validation Acc: 70.1
# Epoch: [4/10], Step: [625/625], Validation Acc: 56.66
# Epoch: [5/10], Step: [625/625], Validation Acc: 69.16
# Epoch: [6/10], Step: [625/625], Validation Acc: 70.76
# Epoch: [7/10], Step: [625/625], Validation Acc: 69.64
# Epoch: [8/10], Step: [625/625], Validation Acc: 63.92
# Epoch: [9/10], Step: [625/625], Validation Acc: 70.88
# Epoch: [10/10], Step: [625/625], Validation Acc: 69.86
# 70.784
#
# Now it is 17 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 71.18
# Epoch: [2/10], Step: [625/625], Validation Acc: 66.58
# Epoch: [3/10], Step: [625/625], Validation Acc: 69.9
# Epoch: [4/10], Step: [625/625], Validation Acc: 71.64
# Epoch: [5/10], Step: [625/625], Validation Acc: 71.56
# Epoch: [6/10], Step: [625/625], Validation Acc: 71.38
# Epoch: [7/10], Step: [625/625], Validation Acc: 71.16
# Epoch: [8/10], Step: [625/625], Validation Acc: 70.6
# Epoch: [9/10], Step: [625/625], Validation Acc: 70.42
# Epoch: [10/10], Step: [625/625], Validation Acc: 70.28
# 70.336
#
# Now it is 18 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 300
# Epoch: [1/10], Step: [625/625], Validation Acc: 62.82
# Epoch: [2/10], Step: [625/625], Validation Acc: 72.74
# Epoch: [3/10], Step: [625/625], Validation Acc: 72.28
# Epoch: [4/10], Step: [625/625], Validation Acc: 69.04
# Epoch: [5/10], Step: [625/625], Validation Acc: 71.0
# Epoch: [6/10], Step: [625/625], Validation Acc: 72.36
# Epoch: [7/10], Step: [625/625], Validation Acc: 70.42
# Epoch: [8/10], Step: [625/625], Validation Acc: 69.1
# Epoch: [9/10], Step: [625/625], Validation Acc: 71.46
# Epoch: [10/10], Step: [625/625], Validation Acc: 71.46
# 71.316
#
# Now it is 19 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 49.7
# Epoch: [2/10], Step: [625/625], Validation Acc: 52.64
# Epoch: [3/10], Step: [625/625], Validation Acc: 57.08
# Epoch: [4/10], Step: [625/625], Validation Acc: 69.32
# Epoch: [5/10], Step: [625/625], Validation Acc: 68.12
# Epoch: [6/10], Step: [625/625], Validation Acc: 66.22
# Epoch: [7/10], Step: [625/625], Validation Acc: 68.96
# Epoch: [8/10], Step: [625/625], Validation Acc: 65.9
# Epoch: [9/10], Step: [625/625], Validation Acc: 69.98
# Epoch: [10/10], Step: [625/625], Validation Acc: 71.12
# 71.672
#
# Now it is 20 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 50.64
# Epoch: [2/10], Step: [625/625], Validation Acc: 50.58
# Epoch: [3/10], Step: [625/625], Validation Acc: 68.92
# Epoch: [4/10], Step: [625/625], Validation Acc: 63.1
# Epoch: [5/10], Step: [625/625], Validation Acc: 56.7
# Epoch: [6/10], Step: [625/625], Validation Acc: 56.9
# Epoch: [7/10], Step: [625/625], Validation Acc: 71.26
# Epoch: [8/10], Step: [625/625], Validation Acc: 66.54
# Epoch: [9/10], Step: [625/625], Validation Acc: 59.52
# Epoch: [10/10], Step: [625/625], Validation Acc: 62.96
# 63.152
#
# Now it is 21 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 51.08
# Epoch: [2/10], Step: [625/625], Validation Acc: 53.2
# Epoch: [3/10], Step: [625/625], Validation Acc: 62.42
# Epoch: [4/10], Step: [625/625], Validation Acc: 66.42
# Epoch: [5/10], Step: [625/625], Validation Acc: 71.94
# Epoch: [6/10], Step: [625/625], Validation Acc: 71.28
# Epoch: [7/10], Step: [625/625], Validation Acc: 72.44
# Epoch: [8/10], Step: [625/625], Validation Acc: 72.54
# Epoch: [9/10], Step: [625/625], Validation Acc: 71.92
# Epoch: [10/10], Step: [625/625], Validation Acc: 72.74
# 72.504
#
# Now it is 22 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 49.7
# Epoch: [2/10], Step: [625/625], Validation Acc: 53.84
# Epoch: [3/10], Step: [625/625], Validation Acc: 62.28
# Epoch: [4/10], Step: [625/625], Validation Acc: 66.1
# Epoch: [5/10], Step: [625/625], Validation Acc: 71.4
# Epoch: [6/10], Step: [625/625], Validation Acc: 71.82
# Epoch: [7/10], Step: [625/625], Validation Acc: 70.16
# Epoch: [8/10], Step: [625/625], Validation Acc: 70.4
# Epoch: [9/10], Step: [625/625], Validation Acc: 72.38
# Epoch: [10/10], Step: [625/625], Validation Acc: 72.2
# 72.564
#
# Now it is 23 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 71.04
# Epoch: [2/10], Step: [625/625], Validation Acc: 72.06
# Epoch: [3/10], Step: [625/625], Validation Acc: 72.32
# Epoch: [4/10], Step: [625/625], Validation Acc: 72.04
# Epoch: [5/10], Step: [625/625], Validation Acc: 71.38
# Epoch: [6/10], Step: [625/625], Validation Acc: 70.92
# Epoch: [7/10], Step: [625/625], Validation Acc: 70.18
# Epoch: [8/10], Step: [625/625], Validation Acc: 70.46
# Epoch: [9/10], Step: [625/625], Validation Acc: 70.18
# Epoch: [10/10], Step: [625/625], Validation Acc: 69.74
# 70.324
#
# Now it is 24 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 400
# Epoch: [1/10], Step: [625/625], Validation Acc: 70.26
# Epoch: [2/10], Step: [625/625], Validation Acc: 65.3
# Epoch: [3/10], Step: [625/625], Validation Acc: 72.86
# Epoch: [4/10], Step: [625/625], Validation Acc: 64.94
# Epoch: [5/10], Step: [625/625], Validation Acc: 71.42
# Epoch: [6/10], Step: [625/625], Validation Acc: 71.9
# Epoch: [7/10], Step: [625/625], Validation Acc: 70.68
# Epoch: [8/10], Step: [625/625], Validation Acc: 72.16
# Epoch: [9/10], Step: [625/625], Validation Acc: 71.94
# Epoch: [10/10], Step: [625/625], Validation Acc: 70.28
# 70.58
#
# Now it is 25 out of 30 combinations
# optimizer = Adam, learning_rate = 0.0005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 49.74
# Epoch: [2/10], Step: [625/625], Validation Acc: 50.5
# Epoch: [3/10], Step: [625/625], Validation Acc: 52.62
# Epoch: [4/10], Step: [625/625], Validation Acc: 62.86
# Epoch: [5/10], Step: [625/625], Validation Acc: 59.1
# Epoch: [6/10], Step: [625/625], Validation Acc: 70.36
# Epoch: [7/10], Step: [625/625], Validation Acc: 68.16
# Epoch: [8/10], Step: [625/625], Validation Acc: 70.36
# Epoch: [9/10], Step: [625/625], Validation Acc: 71.56
# Epoch: [10/10], Step: [625/625], Validation Acc: 72.38
# 72.424
#
# Now it is 26 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.0005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 60.0
# Epoch: [2/10], Step: [625/625], Validation Acc: 50.3
# Epoch: [3/10], Step: [625/625], Validation Acc: 68.08
# Epoch: [4/10], Step: [625/625], Validation Acc: 52.6
# Epoch: [5/10], Step: [625/625], Validation Acc: 57.98
# Epoch: [6/10], Step: [625/625], Validation Acc: 58.3
# Epoch: [7/10], Step: [625/625], Validation Acc: 60.1
# Epoch: [8/10], Step: [625/625], Validation Acc: 70.86
# Epoch: [9/10], Step: [625/625], Validation Acc: 64.78
# Epoch: [10/10], Step: [625/625], Validation Acc: 67.4
# 67.56
#
# Now it is 27 out of 30 combinations
# optimizer = Adam, learning_rate = 0.001, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 49.72
# Epoch: [2/10], Step: [625/625], Validation Acc: 52.88
# Epoch: [3/10], Step: [625/625], Validation Acc: 62.76
# Epoch: [4/10], Step: [625/625], Validation Acc: 69.88
# Epoch: [5/10], Step: [625/625], Validation Acc: 72.16
# Epoch: [6/10], Step: [625/625], Validation Acc: 67.68
# Epoch: [7/10], Step: [625/625], Validation Acc: 69.46
# Epoch: [8/10], Step: [625/625], Validation Acc: 72.22
# Epoch: [9/10], Step: [625/625], Validation Acc: 72.64
# Epoch: [10/10], Step: [625/625], Validation Acc: 72.92
# 72.448
#
# Now it is 28 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.001, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 60.28
# Epoch: [2/10], Step: [625/625], Validation Acc: 49.76
# Epoch: [3/10], Step: [625/625], Validation Acc: 69.34
# Epoch: [4/10], Step: [625/625], Validation Acc: 63.24
# Epoch: [5/10], Step: [625/625], Validation Acc: 70.0
# Epoch: [6/10], Step: [625/625], Validation Acc: 64.4
# Epoch: [7/10], Step: [625/625], Validation Acc: 72.56
# Epoch: [8/10], Step: [625/625], Validation Acc: 72.74
# Epoch: [9/10], Step: [625/625], Validation Acc: 70.98
# Epoch: [10/10], Step: [625/625], Validation Acc: 70.6
# 70.932
#
# Now it is 29 out of 30 combinations
# optimizer = Adam, learning_rate = 0.005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 71.68
# Epoch: [2/10], Step: [625/625], Validation Acc: 71.68
# Epoch: [3/10], Step: [625/625], Validation Acc: 69.36
# Epoch: [4/10], Step: [625/625], Validation Acc: 70.12
# Epoch: [5/10], Step: [625/625], Validation Acc: 70.9
# Epoch: [6/10], Step: [625/625], Validation Acc: 69.84
# Epoch: [7/10], Step: [625/625], Validation Acc: 70.5
# Epoch: [8/10], Step: [625/625], Validation Acc: 69.84
# Epoch: [9/10], Step: [625/625], Validation Acc: 70.26
# Epoch: [10/10], Step: [625/625], Validation Acc: 69.84
# 70.1
#
# Now it is 30 out of 30 combinations
# optimizer = RMSprop, learning_rate = 0.005, emb_dim = 500
# Epoch: [1/10], Step: [625/625], Validation Acc: 62.96
# Epoch: [2/10], Step: [625/625], Validation Acc: 68.96
# Epoch: [3/10], Step: [625/625], Validation Acc: 72.48
# Epoch: [4/10], Step: [625/625], Validation Acc: 73.1
# Epoch: [5/10], Step: [625/625], Validation Acc: 72.74
# Epoch: [6/10], Step: [625/625], Validation Acc: 72.3
# Epoch: [7/10], Step: [625/625], Validation Acc: 72.34
# Epoch: [8/10], Step: [625/625], Validation Acc: 72.14
# Epoch: [9/10], Step: [625/625], Validation Acc: 71.2
# Epoch: [10/10], Step: [625/625], Validation Acc: 71.2
# 71.244
